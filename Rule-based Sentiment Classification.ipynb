# %% [markdown]
# # <center><b>CS5062 (Machine Learning) Assignment II: Rule-based system for Sentiment Classification</b></center>

# %% [markdown]
# #### Mount google drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Colab Notebooks/CS5062ML: Sentiment Analysis
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/Colab Notebooks/CS5062ML: Sentiment Analysis

# %% [markdown]
# #### Import libraries

# %%
import re, random, math, collections, itertools
import numpy as np

# %% [markdown]
# #### Read the datasets

# %%
def readFiles():
    '''
    Reads the samples within each dataset, splits them and saves them to a list. Populates
    the sentiment dictionary with positive and negative sentiments.
    
        Args:
            
        Returns:
            sentimentDictionary(dict): the lookup dictionary
            pos_rt(list): the positive samples from Rotten Tomatoes
            neg_rt(list): the negative samples from Rotten Tomatoes
            pos_nokia(list): the positive samples from the Nokia dataset 
            neg_nokia(list): the negative samples from the Nokia dataset
    '''
    sentimentDictionary = dict()
    #reading pre-labeled input and splitting into lines
    posSentences = open('rt-polarity.pos', 'r', encoding="ISO-8859-1")
    pos_rt = re.split(r'\n', posSentences.read())

    negSentences = open('rt-polarity.neg', 'r', encoding="ISO-8859-1")
    neg_rt = re.split(r'\n', negSentences.read())

    posSentencesNokia = open('nokia-pos.txt', 'r')
    pos_nokia = re.split(r'\n', posSentencesNokia.read())

    negSentencesNokia = open('nokia-neg.txt', 'r', encoding="ISO-8859-1")
    neg_nokia = re.split(r'\n', negSentencesNokia.read())
 
    posDictionary = open('positive-words.txt', 'r', encoding="ISO-8859-1")
    posWordList = posDictionary.readlines()
    posWordList = [line.strip() for line in posWordList if not line.startswith(";") and not line == '\n']
    #posWordList = re.findall(r"[a-z\-]+", posDictionary.read())

    negDictionary = open('negative-words.txt', 'r', encoding="ISO-8859-1")
    negWordList = negDictionary.readlines()
    negWordList = [line.strip() for line in negWordList if not line.startswith(";") and not line == '\n']
    #negWordList = re.findall(r"[a-z\-]+", negDictionary.read())

    for i in posWordList:
        sentimentDictionary[i] = 1
    for i in negWordList:
        sentimentDictionary[i] = -1

    return sentimentDictionary, pos_rt, neg_rt, pos_nokia, neg_nokia

# %%
sent_dict, pos_rt, neg_rt, pos_nokia, neg_nokia = readFiles()

# %%
print('Print total positive words in sentiment dictionary:', sum([v == 1 for v in sent_dict.values()]))
print('Print total negative words in sentiment dictionary:', sum([v == -1 for v in sent_dict.values()]))
# Out:
# Print total positive words in sentiment dictionary: 2003
# Print total negative words in sentiment dictionary: 4783

# %%
print(len(pos_rt), len(neg_rt))
# Out:
# 5332 5332

# %%
print(len(pos_nokia), len(neg_nokia))
# Out:
# 194 80

# %%
def create_dataset(pos_rt, neg_rt):
  '''
    Concatenates the positive and negative samples into one dataset and creates a list of labels.
    
        Args:
            pos_rt(list): the positive samples from the dataset
            neg_rt(list): the negative samples from the dataset
        Returns:
            rt_data(list): the list of concatenated samples
            rt_labels(list): the list of annotations for each sample
  '''
  rt_labels = list()
  rt_data = pos_rt + neg_rt

  for i in range(len(pos_rt)):
    rt_labels.append(1)
  
  for i in range(len(neg_rt)):
    rt_labels.append(0)

  return rt_data, rt_labels

# %% [markdown]
# #### Prepare the Rotten Tomatoes dataset

# %%
rt_data, rt_labels = create_dataset(pos_rt, neg_rt)

# %%
print(sum(v == 1 for v in rt_labels))
print(sum(v == 0 for v in rt_labels))
# Out:
# 5332
# 5332

# %%
print(rt_data[0])
# Out:
# the rock is destined to be the 21st century's new " conan " and that he's going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal .

# %%
#90/10 split
test_size = int(0.1 * len(rt_data))
rt_data_np = np.vstack((rt_data, rt_labels)).T
np.random.shuffle(rt_data_np)
rt_features_train = list(rt_data_np[:, 0][:-test_size])
rt_labels_train = list(rt_data_np[:, 1][:-test_size])
rt_features_test = list(rt_data_np[:, 0][-test_size:])
rt_labels_test = list(rt_data_np[:, 1][-test_size:])

# %% [markdown]
# #### Train the rule-based model

# %%
def classify_rule_based(data, labels, sent_dict, threshold=0, sigma=1, trigram_ps=1, trigram_ns=1):
    '''
      The modified rule-based classification function using trigrams, scoring functions and a 
      weighed coefficient for the threshold values.
      
          Args:
              data(list): the input sentences
              labels(list): the list of annotations
              sent_dict(dict): the lookup dictionary
              threshold(float): the decision boundary for the sentiments
              sigma(float): the weighed coefficient for the threshold
              trigram_ps(int): the scoring weight for the positive samples
              trigram_ns(int): the scoring weight for the negative samples
          Returns:
              mean_f_measure(float): the optimization target - Mean F1-Score
              np.mean(scores)(float): the mean value of all scored samples
    '''
    total=0
    correct=0
    totalpos=0
    totalneg=0
    totalpospred=0
    totalnegpred=0
    correctpos=0
    correctneg=0
    scores = list()
    for i in range(len(data)):
      wordList = re.findall(r"[\w']+", data[i])
      trigramList = wordList.copy()  # initialise trigramList
      for x in range(len(wordList) - 2):
          trigramList.append(wordList[x] + "_" + wordList[x + 1] + "_" + wordList[x + 2])
      
      score = 0
      for trigram in trigramList:
        words = trigram.split("_")
        for word in words:
          cur_score = 0
          if word in sent_dict:
            cur_score+=sent_dict[word]
        if cur_score > 0:
          score+=trigram_ps
        else:
          score-=trigram_ns

      #print('Total score:', score)
      
      scores.append(score)

      total+=1

      if labels[i]=='1':
        totalpos+=1
        if score>threshold*sigma:
          correct+=1
          correctpos+=1
          totalpospred+=1
        else:
          totalnegpred+=1
          if PRINT_ERRORS:
            print ("ERROR (pos classed as neg %0.2f):", data[i])
      else:
        totalneg+=1
        if score<=threshold*sigma:
            correct+=1
            correctneg+=1
            totalnegpred+=1
        else:
            totalpospred+=1
            if PRINT_ERRORS:
              print ("ERROR (neg classed as pos %0.2f):", data[i])

    acc=correct/float(total)
    print('Sigma:', sigma)
    print('Threshold:', threshold)
    print('Mean score:', np.mean(scores))
    print ("Accuracy (All)=%0.2f" % acc + " (%d" % correct + "/%d" % total + ")\n")


    # smoothing to avoid division by zero errors
    precision_pos=correctpos/round(float(totalpospred) + 0.01, 2)
    recall_pos=correctpos/round(float(totalpos) + 0.01, 2)
    precision_neg=correctneg/round(float(totalnegpred) + 0.01, 2)
    recall_neg=correctneg/round(float(totalneg) + 0.01, 2)
    f_pos=2*precision_pos*recall_pos/round(float(precision_pos+recall_pos) + 0.01, 2);
    f_neg=2*precision_neg*recall_neg/round(float(precision_neg+recall_neg) + 0.01, 2);

    print('Positive scores..')
    print("Precision (Pos)=%0.2f" % precision_pos + " (%d" % correctpos + "/%d" % totalpospred + ")")
    print("Recall (Pos)=%0.2f" % recall_pos + " (%d" % correctpos + "/%d" % totalpos + ")")
    print("F-measure (Pos)=%0.2f" % f_pos)

    print('Negative scores..')
    print("Precision (Neg)=%0.2f" % precision_neg + " (%d" % correctneg + "/%d" % totalnegpred + ")")
    print("Recall (Neg)=%0.2f" % recall_neg + " (%d" % correctneg + "/%d" % totalneg + ")")
    print("F-measure (Neg)=%0.2f" % f_neg + "\n")

    print('Mean scores..')
    print("Precision (Mean)={:.2f}".format((precision_pos + precision_neg) / 2))
    print("Recall (Mean)={:.2f}".format((recall_pos + recall_neg) / 2))
    print("F-measure (Mean)={:.2f}".format((f_pos + f_neg) / 2))
    print()

    mean_f_measure = (f_pos + f_neg) / 2
    return mean_f_measure, np.mean(scores)

# %%
PRINT_ERRORS = 0
classify_rule_based(rt_features_test, rt_labels_test, sent_dict, trigram_ps=2, trigram_ns=1)
# Out:
# Sigma: 1
# Threshold: 0
# Mean score: -29.5422138836773
# Accuracy (All)=0.51 (548/1066)
#
# Positive scores..
# Precision (Pos)=0.91 (10/11)
# Recall (Pos)=0.02 (10/527)
# F-measure (Pos)=0.04
# Negative scores..
# Precision (Neg)=0.51 (538/1055)
# Recall (Neg)=1.00 (538/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.71
# Recall (Mean)=0.51
# F-measure (Mean)=0.35
# (0.35319767834640153, -29.5422138836773)

# %% [markdown]
# #### Optimize the model by tuning the $\sigma$(weight coefficient for the threshold) and the scoring functions for the trigrams

# %%
def optimize_rule_based(features_test, labels_test, sent_dict, threshold=0, sigma_range=[-4, 4], trigram_ps=1, trigram_ns=1):
  '''
      The main function for optimizing the rule-based method. Uses the mean sentiment score as the initial threshold
      and does a parameter search for the best sigma.
      
          Args:
              features_test(list): the input sentences
              labels_test(list): the list of annotations
              sent_dict(dict): the lookup dictionary
              threshold(float): the decision boundary for the sentiments
              sigma_range(list): the valid range of sigma for the parameter search
              trigram_ps(int): the scoring weight for the positive samples
              trigram_ns(int): the scoring weight for the negative samples
          Returns:
          
  '''
  #set the threshold as the mean value of the scores and optimize sigma
  sigmas = list(np.linspace(sigma_range[0], sigma_range[1], num=100))
  print('Train with default threshold..')
  fm, mean_score = classify_rule_based(features_test, labels_test, sent_dict)
  threshold = mean_score
  print('Train with optimized threshold, default sigma..')
  fm, _ = classify_rule_based(features_test, labels_test, sent_dict, threshold=threshold)
  print()
  print('Optimizing sigma..')
  best_fm = fm
  best_sigma = 1
  for sigma in sigmas:
    print()
    print('Sigma:', sigma)
    print()
    sig_fm, _ = classify_rule_based(features_test, labels_test, sent_dict, threshold=threshold, 
                                    sigma=sigma, trigram_ps=trigram_ps, trigram_ns=trigram_ns)
    if sig_fm > best_fm:
      print('Found better sigma:', sigma)
      best_fm = sig_fm
      best_sigma = sigma
  
  print()
  print('Final results')
  print('Best mean f-measure:', best_fm)
  print('Best sigma:', best_sigma)
  print('Best threshold:', threshold)

# %%
optimize_rule_based(rt_features_test, rt_labels_test, sent_dict, trigram_ps=8, trigram_ns=1)
# Out:
# Train with default threshold..
# Sigma: 1
# Threshold: 0
# Mean score: -31.79924953095685
# Accuracy (All)=0.51 (540/1066)
#
# Positive scores..
# Precision (Pos)=0.99 (1/1)
# Recall (Pos)=0.00 (1/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1065)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
# Train with optimized threshold, default sigma..
# Sigma: 1
# Threshold: -31.79924953095685
# Mean score: -31.79924953095685
# Accuracy (All)=0.52 (559/1066)
#
# Positive scores..
# Precision (Pos)=0.52 (281/542)
# Recall (Pos)=0.53 (281/527)
# F-measure (Pos)=0.52
# Negative scores..
# Precision (Neg)=0.53 (278/524)
# Recall (Neg)=0.52 (278/539)
# F-measure (Neg)=0.52
#
# Mean scores..
# Precision (Mean)=0.52
# Recall (Mean)=0.52
# F-measure (Mean)=0.52
#
#
# Optimizing sigma..
#
# Sigma: -4.0
#
# Sigma: -4.0
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.919191919191919
#
# Sigma: -3.919191919191919
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.8383838383838382
#
# Sigma: -3.8383838383838382
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.757575757575758
#
# Sigma: -3.757575757575758
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.676767676767677
#
# Sigma: -3.676767676767677
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.595959595959596
#
# Sigma: -3.595959595959596
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.515151515151515
#
# Sigma: -3.515151515151515
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.4343434343434343
#
# Sigma: -3.4343434343434343
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.3535353535353534
#
# Sigma: -3.3535353535353534
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.2727272727272725
#
# Sigma: -3.2727272727272725
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.191919191919192
#
# Sigma: -3.191919191919192
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.111111111111111
#
# Sigma: -3.111111111111111
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -3.0303030303030303
#
# Sigma: -3.0303030303030303
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.9494949494949494
#
# Sigma: -2.9494949494949494
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.8686868686868685
#
# Sigma: -2.8686868686868685
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.787878787878788
#
# Sigma: -2.787878787878788
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.7070707070707067
#
# Sigma: -2.7070707070707067
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.6262626262626263
#
# Sigma: -2.6262626262626263
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.5454545454545454
#
# Sigma: -2.5454545454545454
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.4646464646464645
#
# Sigma: -2.4646464646464645
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.3838383838383836
#
# Sigma: -2.3838383838383836
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.3030303030303028
#
# Sigma: -2.3030303030303028
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.2222222222222223
#
# Sigma: -2.2222222222222223
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.141414141414141
#
# Sigma: -2.141414141414141
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -2.0606060606060606
#
# Sigma: -2.0606060606060606
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -1.9797979797979797
#
# Sigma: -1.9797979797979797
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -1.8989898989898988
#
# Sigma: -1.8989898989898988
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (539/1066)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/527)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.51 (539/1066)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: -1.818181818181818
#
# Sigma: -1.818181818181818
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (541/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (2/2)
# Recall (Pos)=0.00 (2/527)
# F-measure (Pos)=0.01
# Negative scores..
# Precision (Neg)=0.51 (539/1064)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: -1.737373737373737
#
# Sigma: -1.737373737373737
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (542/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (3/3)
# Recall (Pos)=0.01 (3/527)
# F-measure (Pos)=0.01
# Negative scores..
# Precision (Neg)=0.51 (539/1063)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: -1.6565656565656566
#
# Sigma: -1.6565656565656566
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (542/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (3/3)
# Recall (Pos)=0.01 (3/527)
# F-measure (Pos)=0.01
# Negative scores..
# Precision (Neg)=0.51 (539/1063)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: -1.5757575757575757
#
# Sigma: -1.5757575757575757
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (542/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (3/3)
# Recall (Pos)=0.01 (3/527)
# F-measure (Pos)=0.01
# Negative scores..
# Precision (Neg)=0.51 (539/1063)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: -1.4949494949494948
#
# Sigma: -1.4949494949494948
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (542/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (3/3)
# Recall (Pos)=0.01 (3/527)
# F-measure (Pos)=0.01
# Negative scores..
# Precision (Neg)=0.51 (539/1063)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: -1.414141414141414
#
# Sigma: -1.414141414141414
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (543/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (4/4)
# Recall (Pos)=0.01 (4/527)
# F-measure (Pos)=0.01
# Negative scores..
# Precision (Neg)=0.51 (539/1062)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: -1.333333333333333
#
# Sigma: -1.333333333333333
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (545/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (6/6)
# Recall (Pos)=0.01 (6/527)
# F-measure (Pos)=0.02
# Negative scores..
# Precision (Neg)=0.51 (539/1060)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.51
# F-measure (Mean)=0.35
#
#
# Sigma: -1.2525252525252522
#
# Sigma: -1.2525252525252522
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (548/1066)
#
# Positive scores..
# Precision (Pos)=1.00 (9/9)
# Recall (Pos)=0.02 (9/527)
# F-measure (Pos)=0.03
# Negative scores..
# Precision (Neg)=0.51 (539/1057)
# Recall (Neg)=1.00 (539/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.51
# F-measure (Mean)=0.35
#
#
# Sigma: -1.1717171717171713
#
# Sigma: -1.1717171717171713
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (548/1066)
#
# Positive scores..
# Precision (Pos)=0.91 (10/11)
# Recall (Pos)=0.02 (10/527)
# F-measure (Pos)=0.04
# Negative scores..
# Precision (Neg)=0.51 (538/1055)
# Recall (Neg)=1.00 (538/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.71
# Recall (Mean)=0.51
# F-measure (Mean)=0.35
#
#
# Sigma: -1.0909090909090908
#
# Sigma: -1.0909090909090908
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.52 (552/1066)
#
# Positive scores..
# Precision (Pos)=0.93 (14/15)
# Recall (Pos)=0.03 (14/527)
# F-measure (Pos)=0.05
# Negative scores..
# Precision (Neg)=0.51 (538/1051)
# Recall (Neg)=1.00 (538/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.72
# Recall (Mean)=0.51
# F-measure (Mean)=0.36
#
#
# Sigma: -1.01010101010101
#
# Sigma: -1.01010101010101
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.52 (556/1066)
#
# Positive scores..
# Precision (Pos)=0.95 (18/19)
# Recall (Pos)=0.03 (18/527)
# F-measure (Pos)=0.07
# Negative scores..
# Precision (Neg)=0.51 (538/1047)
# Recall (Neg)=1.00 (538/539)
# F-measure (Neg)=0.67
#
# Mean scores..
# Precision (Mean)=0.73
# Recall (Mean)=0.52
# F-measure (Mean)=0.37
#
#
# Sigma: -0.9292929292929291
#
# Sigma: -0.9292929292929291
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (560/1066)
#
# Positive scores..
# Precision (Pos)=0.92 (23/25)
# Recall (Pos)=0.04 (23/527)
# F-measure (Pos)=0.08
# Negative scores..
# Precision (Neg)=0.52 (537/1041)
# Recall (Neg)=1.00 (537/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.72
# Recall (Mean)=0.52
# F-measure (Mean)=0.38
#
#
# Sigma: -0.8484848484848482
#
# Sigma: -0.8484848484848482
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (563/1066)
#
# Positive scores..
# Precision (Pos)=0.90 (27/30)
# Recall (Pos)=0.05 (27/527)
# F-measure (Pos)=0.10
# Negative scores..
# Precision (Neg)=0.52 (536/1036)
# Recall (Neg)=0.99 (536/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.71
# Recall (Mean)=0.52
# F-measure (Mean)=0.39
#
#
# Sigma: -0.7676767676767673
#
# Sigma: -0.7676767676767673
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (566/1066)
#
# Positive scores..
# Precision (Pos)=0.89 (31/35)
# Recall (Pos)=0.06 (31/527)
# F-measure (Pos)=0.11
# Negative scores..
# Precision (Neg)=0.52 (535/1031)
# Recall (Neg)=0.99 (535/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.70
# Recall (Mean)=0.53
# F-measure (Mean)=0.39
#
#
# Sigma: -0.6868686868686864
#
# Sigma: -0.6868686868686864
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.54 (574/1066)
#
# Positive scores..
# Precision (Pos)=0.87 (41/47)
# Recall (Pos)=0.08 (41/527)
# F-measure (Pos)=0.14
# Negative scores..
# Precision (Neg)=0.52 (533/1019)
# Recall (Neg)=0.99 (533/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.70
# Recall (Mean)=0.53
# F-measure (Mean)=0.41
#
#
# Sigma: -0.606060606060606
#
# Sigma: -0.606060606060606
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.54 (575/1066)
#
# Positive scores..
# Precision (Pos)=0.82 (46/56)
# Recall (Pos)=0.09 (46/527)
# F-measure (Pos)=0.16
# Negative scores..
# Precision (Neg)=0.52 (529/1010)
# Recall (Neg)=0.98 (529/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.67
# Recall (Mean)=0.53
# F-measure (Mean)=0.42
#
#
# Sigma: -0.5252525252525251
#
# Sigma: -0.5252525252525251
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.55 (583/1066)
#
# Positive scores..
# Precision (Pos)=0.81 (57/70)
# Recall (Pos)=0.11 (57/527)
# F-measure (Pos)=0.19
# Negative scores..
# Precision (Neg)=0.53 (526/996)
# Recall (Neg)=0.98 (526/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.67
# Recall (Mean)=0.54
# F-measure (Mean)=0.44
#
#
# Sigma: -0.4444444444444442
#
# Sigma: -0.4444444444444442
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.55 (584/1066)
#
# Positive scores..
# Precision (Pos)=0.78 (62/79)
# Recall (Pos)=0.12 (62/527)
# F-measure (Pos)=0.20
# Negative scores..
# Precision (Neg)=0.53 (522/987)
# Recall (Neg)=0.97 (522/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.66
# Recall (Mean)=0.54
# F-measure (Mean)=0.44
#
#
# Sigma: -0.3636363636363633
#
# Sigma: -0.3636363636363633
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.56 (592/1066)
#
# Positive scores..
# Precision (Pos)=0.76 (78/103)
# Recall (Pos)=0.15 (78/527)
# F-measure (Pos)=0.24
# Negative scores..
# Precision (Neg)=0.53 (514/963)
# Recall (Neg)=0.95 (514/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.55
# F-measure (Mean)=0.46
#
#
# Sigma: -0.28282828282828243
#
# Sigma: -0.28282828282828243
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.57 (604/1066)
#
# Positive scores..
# Precision (Pos)=0.74 (101/137)
# Recall (Pos)=0.19 (101/527)
# F-measure (Pos)=0.30
# Negative scores..
# Precision (Neg)=0.54 (503/929)
# Recall (Neg)=0.93 (503/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.64
# Recall (Mean)=0.56
# F-measure (Mean)=0.49
#
#
# Sigma: -0.20202020202020154
#
# Sigma: -0.20202020202020154
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.58 (621/1066)
#
# Positive scores..
# Precision (Pos)=0.75 (122/162)
# Recall (Pos)=0.23 (122/527)
# F-measure (Pos)=0.35
# Negative scores..
# Precision (Neg)=0.55 (499/904)
# Recall (Neg)=0.93 (499/539)
# F-measure (Neg)=0.69
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.58
# F-measure (Mean)=0.52
#
# Found better sigma: -0.20202020202020154
#
# Sigma: -0.1212121212121211
#
# Sigma: -0.1212121212121211
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.59 (625/1066)
#
# Positive scores..
# Precision (Pos)=0.71 (144/202)
# Recall (Pos)=0.27 (144/527)
# F-measure (Pos)=0.39
# Negative scores..
# Precision (Neg)=0.56 (481/864)
# Recall (Neg)=0.89 (481/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.63
# Recall (Mean)=0.58
# F-measure (Mean)=0.54
#
# Found better sigma: -0.1212121212121211
#
# Sigma: -0.04040404040404022
#
# Sigma: -0.04040404040404022
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.59 (634/1066)
#
# Positive scores..
# Precision (Pos)=0.71 (160/225)
# Recall (Pos)=0.30 (160/527)
# F-measure (Pos)=0.42
# Negative scores..
# Precision (Neg)=0.56 (474/841)
# Recall (Neg)=0.88 (474/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.64
# Recall (Mean)=0.59
# F-measure (Mean)=0.55
#
# Found better sigma: -0.04040404040404022
#
# Sigma: 0.040404040404040664
#
# Sigma: 0.040404040404040664
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.61 (645/1066)
#
# Positive scores..
# Precision (Pos)=0.70 (183/260)
# Recall (Pos)=0.35 (183/527)
# F-measure (Pos)=0.46
# Negative scores..
# Precision (Neg)=0.57 (462/806)
# Recall (Neg)=0.86 (462/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.64
# Recall (Mean)=0.60
# F-measure (Mean)=0.57
#
# Found better sigma: 0.040404040404040664
#
# Sigma: 0.12121212121212199
#
# Sigma: 0.12121212121212199
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.62 (657/1066)
#
# Positive scores..
# Precision (Pos)=0.70 (205/292)
# Recall (Pos)=0.39 (205/527)
# F-measure (Pos)=0.50
# Negative scores..
# Precision (Neg)=0.58 (452/774)
# Recall (Neg)=0.84 (452/539)
# F-measure (Neg)=0.68
#
# Mean scores..
# Precision (Mean)=0.64
# Recall (Mean)=0.61
# F-measure (Mean)=0.59
#
# Found better sigma: 0.12121212121212199
#
# Sigma: 0.20202020202020243
#
# Sigma: 0.20202020202020243
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.61 (654/1066)
#
# Positive scores..
# Precision (Pos)=0.66 (238/361)
# Recall (Pos)=0.45 (238/527)
# F-measure (Pos)=0.53
# Negative scores..
# Precision (Neg)=0.59 (416/705)
# Recall (Neg)=0.77 (416/539)
# F-measure (Neg)=0.66
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.61
# F-measure (Mean)=0.60
#
# Found better sigma: 0.20202020202020243
#
# Sigma: 0.2828282828282829
#
# Sigma: 0.2828282828282829
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.61 (653/1066)
#
# Positive scores..
# Precision (Pos)=0.64 (255/396)
# Recall (Pos)=0.48 (255/527)
# F-measure (Pos)=0.55
# Negative scores..
# Precision (Neg)=0.59 (398/670)
# Recall (Neg)=0.74 (398/539)
# F-measure (Neg)=0.65
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.61
# F-measure (Mean)=0.60
#
# Found better sigma: 0.2828282828282829
#
# Sigma: 0.3636363636363642
#
# Sigma: 0.3636363636363642
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.61 (648/1066)
#
# Positive scores..
# Precision (Pos)=0.63 (268/427)
# Recall (Pos)=0.51 (268/527)
# F-measure (Pos)=0.56
# Negative scores..
# Precision (Neg)=0.59 (380/639)
# Recall (Neg)=0.70 (380/539)
# F-measure (Neg)=0.64
#
# Mean scores..
# Precision (Mean)=0.61
# Recall (Mean)=0.61
# F-measure (Mean)=0.60
#
#
# Sigma: 0.44444444444444464
#
# Sigma: 0.44444444444444464
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.60 (637/1066)
#
# Positive scores..
# Precision (Pos)=0.60 (297/496)
# Recall (Pos)=0.56 (297/527)
# F-measure (Pos)=0.58
# Negative scores..
# Precision (Neg)=0.60 (340/570)
# Recall (Neg)=0.63 (340/539)
# F-measure (Neg)=0.61
#
# Mean scores..
# Precision (Mean)=0.60
# Recall (Mean)=0.60
# F-measure (Mean)=0.59
#
#
# Sigma: 0.525252525252526
#
# Sigma: 0.525252525252526
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.59 (629/1066)
#
# Positive scores..
# Precision (Pos)=0.58 (315/540)
# Recall (Pos)=0.60 (315/527)
# F-measure (Pos)=0.59
# Negative scores..
# Precision (Neg)=0.60 (314/526)
# Recall (Neg)=0.58 (314/539)
# F-measure (Neg)=0.58
#
# Mean scores..
# Precision (Mean)=0.59
# Recall (Mean)=0.59
# F-measure (Mean)=0.59
#
#
# Sigma: 0.6060606060606064
#
# Sigma: 0.6060606060606064
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.58 (616/1066)
#
# Positive scores..
# Precision (Pos)=0.57 (329/581)
# Recall (Pos)=0.62 (329/527)
# F-measure (Pos)=0.59
# Negative scores..
# Precision (Neg)=0.59 (287/485)
# Recall (Neg)=0.53 (287/539)
# F-measure (Neg)=0.56
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.58
# F-measure (Mean)=0.57
#
#
# Sigma: 0.6868686868686869
#
# Sigma: 0.6868686868686869
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.58 (614/1066)
#
# Positive scores..
# Precision (Pos)=0.56 (346/617)
# Recall (Pos)=0.66 (346/527)
# F-measure (Pos)=0.60
# Negative scores..
# Precision (Neg)=0.60 (268/449)
# Recall (Neg)=0.50 (268/539)
# F-measure (Neg)=0.54
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.58
# F-measure (Mean)=0.57
#
#
# Sigma: 0.7676767676767682
#
# Sigma: 0.7676767676767682
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.56 (594/1066)
#
# Positive scores..
# Precision (Pos)=0.54 (377/699)
# Recall (Pos)=0.72 (377/527)
# F-measure (Pos)=0.61
# Negative scores..
# Precision (Neg)=0.59 (217/367)
# Recall (Neg)=0.40 (217/539)
# F-measure (Neg)=0.48
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.56
# F-measure (Mean)=0.54
#
#
# Sigma: 0.8484848484848486
#
# Sigma: 0.8484848484848486
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.55 (591/1066)
#
# Positive scores..
# Precision (Pos)=0.54 (394/736)
# Recall (Pos)=0.75 (394/527)
# F-measure (Pos)=0.62
# Negative scores..
# Precision (Neg)=0.60 (197/330)
# Recall (Neg)=0.37 (197/539)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.56
# F-measure (Mean)=0.54
#
#
# Sigma: 0.92929292929293
#
# Sigma: 0.92929292929293
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.54 (580/1066)
#
# Positive scores..
# Precision (Pos)=0.53 (410/779)
# Recall (Pos)=0.78 (410/527)
# F-measure (Pos)=0.63
# Negative scores..
# Precision (Neg)=0.59 (170/287)
# Recall (Neg)=0.32 (170/539)
# F-measure (Neg)=0.41
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.55
# F-measure (Mean)=0.52
#
#
# Sigma: 1.0101010101010104
#
# Sigma: 1.0101010101010104
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.54 (571/1066)
#
# Positive scores..
# Precision (Pos)=0.52 (437/842)
# Recall (Pos)=0.83 (437/527)
# F-measure (Pos)=0.63
# Negative scores..
# Precision (Neg)=0.60 (134/224)
# Recall (Neg)=0.25 (134/539)
# F-measure (Neg)=0.35
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.54
# F-measure (Mean)=0.49
#
#
# Sigma: 1.0909090909090917
#
# Sigma: 1.0909090909090917
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (567/1066)
#
# Positive scores..
# Precision (Pos)=0.52 (449/870)
# Recall (Pos)=0.85 (449/527)
# F-measure (Pos)=0.64
# Negative scores..
# Precision (Neg)=0.60 (118/196)
# Recall (Neg)=0.22 (118/539)
# F-measure (Neg)=0.32
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.54
# F-measure (Mean)=0.48
#
#
# Sigma: 1.1717171717171722
#
# Sigma: 1.1717171717171722
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (561/1066)
#
# Positive scores..
# Precision (Pos)=0.51 (458/894)
# Recall (Pos)=0.87 (458/527)
# F-measure (Pos)=0.64
# Negative scores..
# Precision (Neg)=0.60 (103/172)
# Recall (Neg)=0.19 (103/539)
# F-measure (Neg)=0.29
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.53
# F-measure (Mean)=0.46
#
#
# Sigma: 1.2525252525252526
#
# Sigma: 1.2525252525252526
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (569/1066)
#
# Positive scores..
# Precision (Pos)=0.52 (476/922)
# Recall (Pos)=0.90 (476/527)
# F-measure (Pos)=0.65
# Negative scores..
# Precision (Neg)=0.65 (93/144)
# Recall (Neg)=0.17 (93/539)
# F-measure (Neg)=0.27
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.54
# F-measure (Mean)=0.46
#
#
# Sigma: 1.333333333333334
#
# Sigma: 1.333333333333334
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (561/1066)
#
# Positive scores..
# Precision (Pos)=0.51 (488/954)
# Recall (Pos)=0.93 (488/527)
# F-measure (Pos)=0.65
# Negative scores..
# Precision (Neg)=0.65 (73/112)
# Recall (Neg)=0.14 (73/539)
# F-measure (Neg)=0.22
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.53
# F-measure (Mean)=0.44
#
#
# Sigma: 1.4141414141414144
#
# Sigma: 1.4141414141414144
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.53 (562/1066)
#
# Positive scores..
# Precision (Pos)=0.51 (497/971)
# Recall (Pos)=0.94 (497/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.68 (65/95)
# Recall (Neg)=0.12 (65/539)
# F-measure (Neg)=0.20
#
# Mean scores..
# Precision (Mean)=0.60
# Recall (Mean)=0.53
# F-measure (Mean)=0.43
#
#
# Sigma: 1.4949494949494957
#
# Sigma: 1.4949494949494957
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.52 (554/1066)
#
# Positive scores..
# Precision (Pos)=0.51 (501/987)
# Recall (Pos)=0.95 (501/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.67 (53/79)
# Recall (Neg)=0.10 (53/539)
# F-measure (Neg)=0.17
#
# Mean scores..
# Precision (Mean)=0.59
# Recall (Mean)=0.52
# F-measure (Mean)=0.41
#
#
# Sigma: 1.5757575757575761
#
# Sigma: 1.5757575757575761
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.52 (549/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (510/1010)
# Recall (Pos)=0.97 (510/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.70 (39/56)
# Recall (Neg)=0.07 (39/539)
# F-measure (Neg)=0.13
#
# Mean scores..
# Precision (Mean)=0.60
# Recall (Mean)=0.52
# F-measure (Mean)=0.39
#
#
# Sigma: 1.6565656565656575
#
# Sigma: 1.6565656565656575
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (540/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (511/1021)
# Recall (Pos)=0.97 (511/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.64 (29/45)
# Recall (Neg)=0.05 (29/539)
# F-measure (Neg)=0.10
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.51
# F-measure (Mean)=0.38
#
#
# Sigma: 1.737373737373738
#
# Sigma: 1.737373737373738
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.51 (541/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (515/1028)
# Recall (Pos)=0.98 (515/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.68 (26/38)
# Recall (Neg)=0.05 (26/539)
# F-measure (Neg)=0.09
#
# Mean scores..
# Precision (Mean)=0.59
# Recall (Mean)=0.51
# F-measure (Mean)=0.37
#
#
# Sigma: 1.8181818181818183
#
# Sigma: 1.8181818181818183
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (536/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (517/1037)
# Recall (Pos)=0.98 (517/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.65 (19/29)
# Recall (Neg)=0.04 (19/539)
# F-measure (Neg)=0.07
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.51
# F-measure (Mean)=0.36
#
#
# Sigma: 1.8989898989898997
#
# Sigma: 1.8989898989898997
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (533/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (522/1050)
# Recall (Pos)=0.99 (522/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.69 (11/16)
# Recall (Neg)=0.02 (11/539)
# F-measure (Neg)=0.04
#
# Mean scores..
# Precision (Mean)=0.59
# Recall (Mean)=0.51
# F-measure (Mean)=0.35
#
#
# Sigma: 1.9797979797979801
#
# Sigma: 1.9797979797979801
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (532/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (523/1053)
# Recall (Pos)=0.99 (523/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.69 (9/13)
# Recall (Neg)=0.02 (9/539)
# F-measure (Neg)=0.03
#
# Mean scores..
# Precision (Mean)=0.59
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.0606060606060614
#
# Sigma: 2.0606060606060614
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (531/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (524/1056)
# Recall (Pos)=0.99 (524/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.70 (7/10)
# Recall (Neg)=0.01 (7/539)
# F-measure (Neg)=0.03
#
# Mean scores..
# Precision (Mean)=0.60
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.141414141414142
#
# Sigma: 2.141414141414142
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (530/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (526/1061)
# Recall (Pos)=1.00 (526/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.80 (4/5)
# Recall (Neg)=0.01 (4/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.2222222222222223
#
# Sigma: 2.2222222222222223
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (530/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (526/1061)
# Recall (Pos)=1.00 (526/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.80 (4/5)
# Recall (Neg)=0.01 (4/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.3030303030303036
#
# Sigma: 2.3030303030303036
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (530/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (526/1061)
# Recall (Pos)=1.00 (526/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.80 (4/5)
# Recall (Neg)=0.01 (4/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.383838383838384
#
# Sigma: 2.383838383838384
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (529/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (526/1062)
# Recall (Pos)=1.00 (526/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.75 (3/4)
# Recall (Neg)=0.01 (3/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.4646464646464654
#
# Sigma: 2.4646464646464654
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (529/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (526/1062)
# Recall (Pos)=1.00 (526/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.75 (3/4)
# Recall (Neg)=0.01 (3/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.545454545454546
#
# Sigma: 2.545454545454546
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (529/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (526/1062)
# Recall (Pos)=1.00 (526/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.75 (3/4)
# Recall (Neg)=0.01 (3/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 2.626262626262627
#
# Sigma: 2.626262626262627
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (530/1066)
#
# Positive scores..
# Precision (Pos)=0.50 (527/1063)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=1.00 (3/3)
# Recall (Neg)=0.01 (3/539)
# F-measure (Neg)=0.01
#
# Mean scores..
# Precision (Mean)=0.75
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 2.7070707070707076
#
# Sigma: 2.7070707070707076
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.50 (528/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1065)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.99 (1/1)
# Recall (Neg)=0.00 (1/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.74
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 2.787878787878788
#
# Sigma: 2.787878787878788
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 2.8686868686868694
#
# Sigma: 2.8686868686868694
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 2.94949494949495
#
# Sigma: 2.94949494949495
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.030303030303031
#
# Sigma: 3.030303030303031
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.1111111111111116
#
# Sigma: 3.1111111111111116
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.191919191919193
#
# Sigma: 3.191919191919193
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.2727272727272734
#
# Sigma: 3.2727272727272734
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.353535353535354
#
# Sigma: 3.353535353535354
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.434343434343435
#
# Sigma: 3.434343434343435
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.5151515151515156
#
# Sigma: 3.5151515151515156
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.595959595959597
#
# Sigma: 3.595959595959597
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.6767676767676774
#
# Sigma: 3.6767676767676774
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.757575757575758
#
# Sigma: 3.757575757575758
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.838383838383839
#
# Sigma: 3.838383838383839
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 3.9191919191919196
#
# Sigma: 3.9191919191919196
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Sigma: 4.0
#
# Sigma: 4.0
# Threshold: -31.79924953095685
# Mean score: -16.0
# Accuracy (All)=0.49 (527/1066)
#
# Positive scores..
# Precision (Pos)=0.49 (527/1066)
# Recall (Pos)=1.00 (527/527)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.00 (0/0)
# Recall (Neg)=0.00 (0/539)
# F-measure (Neg)=0.00
#
# Mean scores..
# Precision (Mean)=0.25
# Recall (Mean)=0.50
# F-measure (Mean)=0.33
#
#
# Final results
# Best mean f-measure: 0.6006349014666212
# Best sigma: 0.2828282828282829
# Best threshold: -31.79924953095685

# %%
classify_rule_based(rt_features_test, rt_labels_test, sent_dict, threshold=-31.44, sigma=0.28, trigram_ps=8, trigram_ns=1)
# Out:
# Sigma: 0.28
# Threshold: -31.44
# Mean score: -16.0
# Accuracy (All)=0.61 (653/1066)
#
# Positive scores..
# Precision (Pos)=0.64 (255/396)
# Recall (Pos)=0.48 (255/527)
# F-measure (Pos)=0.55
# Negative scores..
# Precision (Neg)=0.59 (398/670)
# Recall (Neg)=0.74 (398/539)
# F-measure (Neg)=0.65
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.61
# F-measure (Mean)=0.60
# (0.6006349014666212, -16.0)

# %%
PRINT_ERRORS=1
classify_rule_based(rt_features_test, rt_labels_test, sent_dict, threshold=-31.44, sigma=0.28, trigram_ps=8, trigram_ns=1)
PRINT_ERRORS=0
# Out:
# ERROR (pos classed as neg %0.2f): this enthralling documentary . . . is at once playful and haunting , an in-depth portrait of an iconoclastic artist who was fundamentally unknowable even to his closest friends .
# ERROR (pos classed as neg %0.2f): some people march to the beat of a different drum , and if you ever wondered what kind of houses those people live in , this documentary takes a look at 5 alternative housing options .
# ERROR (neg classed as pos %0.2f): the leads we are given here are simply too bland to be interesting .
# ERROR (pos classed as neg %0.2f): the trinity assembly approaches the endeavor with a shocking lack of irony , and george ratliff's documentary , hell house , reflects their earnestness  which makes for a terrifying film .
# ERROR (pos classed as neg %0.2f): despite the long running time , the pace never feels slack -- there's no scene that screams " bathroom break ! "
# ERROR (pos classed as neg %0.2f): although it lacks the detail of the book , the film does pack some serious suspense .
# ERROR (pos classed as neg %0.2f): insomnia does not become one of those rare remakes to eclipse the original , but it doesn't disgrace it , either .
# ERROR (pos classed as neg %0.2f): an intriguing look at the french film industry during the german occupation ; its most delightful moments come when various characters express their quirky inner selves .
# ERROR (pos classed as neg %0.2f): could use a little more humanity , but it never lacks in eye-popping visuals .
# ERROR (neg classed as pos %0.2f): to portray modern women the way director davis has done is just unthinkable .
# ERROR (pos classed as neg %0.2f): the subtitled costume drama is set in a remote african empire before cell phones , guns , and the internal combustion engine , but the politics that thump through it are as timely as tomorrow .
# ERROR (pos classed as neg %0.2f): don't judge this one too soon - it's a dark , gritty story but it takes off in totally unexpected directions and keeps on going .
# ERROR (neg classed as pos %0.2f): rashomon-for-dipsticks tale .
# ERROR (pos classed as neg %0.2f): the work of an artist tormented by his heritage , using his storytelling ability to honor the many faceless victims .
# ERROR (pos classed as neg %0.2f): equilibrium is what george orwell might have imagined had today's mood-altering drug therapy been envisioned by chemists in 1949 .
# ERROR (neg classed as pos %0.2f): it has become apparent that the franchise's best years are long past .
# ERROR (pos classed as neg %0.2f): by the time we learn that andrew's turnabout is fair play is every bit as awful as borchardt's coven , we can enjoy it anyway .
# ERROR (neg classed as pos %0.2f): an extraordinarily silly thriller .
# ERROR (pos classed as neg %0.2f): it's refreshing to see a movie that embraces its old-fashioned themes and in the process comes out looking like something wholly original .
# ERROR (pos classed as neg %0.2f): if reno is to the left of liberal on the political spectrum , her tough , funny , rather chaotic show isn't subversive so much as it is nit-picky about the hypocrisies of our time .
# ERROR (pos classed as neg %0.2f): if you are an actor who can relate to the search for inner peace by dramatically depicting the lives of others onstage , then esther's story is a compelling quest for truth .
# ERROR (pos classed as neg %0.2f): bursting through the constraints of its source , this is one adapted- from-television movie that actually looks as if it belongs on the big screen .
# ERROR (neg classed as pos %0.2f): so relentlessly wholesome it made me want to swipe something .
# ERROR (pos classed as neg %0.2f): an endlessly fascinating , landmark movie that is as bold as anything the cinema has seen in years .
# ERROR (pos classed as neg %0.2f): i liked about schmidt a lot , but i have a feeling that i would have liked it much more if harry & tonto never existed .
# ERROR (pos classed as neg %0.2f): a refreshing korean film about five female high school friends who face an uphill battle when they try to take their relationships into deeper waters .
# ERROR (pos classed as neg %0.2f): nicole holofcener's lovely and amazing , from her own screenplay , jumps to the head of the class of women's films that manage to avoid the ghetto of sentimental chick-flicks by treating female follies with a satirical style .
# ERROR (neg classed as pos %0.2f): has all the right elements but completely fails to gel together .
# ERROR (pos classed as neg %0.2f): the pinochet case is a searing album of remembrance from those who , having survived , suffered most .
# ERROR (pos classed as neg %0.2f): in adobo , ethnicity is not just the spice , but at the heart of more universal concerns .
# ERROR (pos classed as neg %0.2f): it is different from others in its genre in that it is does not rely on dumb gags , anatomical humor , or character cliches ; it primarily relies on character to tell its story .
# ERROR (pos classed as neg %0.2f): while not all transitions to adulthood are so fraught , there's much truth and no small amount of poetry in girls can't swim .
# ERROR (neg classed as pos %0.2f): bears is bad . not 'terrible filmmaking' bad , but more like , 'i once had a nightmare like this , and it's now coming true' bad .
# ERROR (neg classed as pos %0.2f): downbeat , period-perfect biopic hammers home a heavy-handed moralistic message .
# ERROR (neg classed as pos %0.2f): a chiller resolutely without chills .
# ERROR (neg classed as pos %0.2f): mariah carey gives us another peek at some of the magic we saw in glitter here in wisegirls .
# ERROR (neg classed as pos %0.2f): perfectly enjoyable , instantly forgettable , nothing to write home about .
# ERROR (neg classed as pos %0.2f): sayles . . . once again strands his superb performers in the same old story .
# ERROR (neg classed as pos %0.2f): schindler's list it ain't .
# ERROR (pos classed as neg %0.2f): neither quite a comedy nor a romance , more of an impish divertissement of themes that interest attal and gainsbourg -- they live together -- the film has a lot of charm .
# ERROR (pos classed as neg %0.2f): allen shows he can outgag any of those young whippersnappers making moving pictures today .
# ERROR (neg classed as pos %0.2f): [t]hose same extremes prevent us from taking its message seriously , and the stepford wives mentality doesn't work in a modern context .
# ERROR (pos classed as neg %0.2f): while the ideas about techno-saturation are far from novel , they're presented with a wry dark humor .
# ERROR (pos classed as neg %0.2f): the filmmakers skillfully evoke the sense of menace that nature holds for many urban dwellers .
# ERROR (pos classed as neg %0.2f): based on a devilishly witty script by heather mcgowan and niels mueller , the film gets great laughs , but never at the expense of its characters
# ERROR (neg classed as pos %0.2f): oozes condescension from every pore .
# ERROR (neg classed as pos %0.2f): so exaggerated and broad that it comes off as annoying rather than charming .
# ERROR (pos classed as neg %0.2f): shiner can certainly go the distance , but isn't world championship material
# ERROR (neg classed as pos %0.2f): sam mendes has become valedictorian at the school for soft landings and easy ways out .
# ERROR (neg classed as pos %0.2f): the film's essentially over by the meet-cute .
# ERROR (pos classed as neg %0.2f): the underworld urban angst is derivative of martin scorsese's taxi driver and goodfellas , but this film speaks for itself .
# ERROR (pos classed as neg %0.2f): often moving and explores the discomfort inherent in the contacts between the american 'hosts' and their 'guests . '
# ERROR (neg classed as pos %0.2f): oh , it's extreme , all right . extremely dumb . extremely confusing . extremely boring .
# ERROR (neg classed as pos %0.2f): [w]hile long on amiable monkeys and worthy environmentalism , jane goodall's wild chimpanzees is short on the thrills the oversize medium demands .
# ERROR (pos classed as neg %0.2f): a high-spirited buddy movie about the reunion of berlin anarchists who face arrest 15 years after their crime .
# ERROR (pos classed as neg %0.2f): frailty isn't as gory or explicit . but in its child-centered , claustrophobic context , it can be just as frightening and disturbing -- even punishing .
# ERROR (pos classed as neg %0.2f): a must see for all sides of the political spectrum
# ERROR (pos classed as neg %0.2f): takashi miike keeps pushing the envelope : ichi the killer
# ERROR (pos classed as neg %0.2f): a coming-of-age film that avoids the cartoonish clichés and sneering humor of the genre as it provides a fresh view of an old type -- the uncertain girl on the brink of womanhood .
# ERROR (neg classed as pos %0.2f): there's an excellent 90-minute film here ; unfortunately , it runs for 170 .
# ERROR (pos classed as neg %0.2f): the fluid motion is astounding on any number of levels -- including the physical demands made on büttner -- and it implies in its wake the intractable , irreversible flow of history .
# ERROR (neg classed as pos %0.2f): the cartoon that isn't really good enough to be on afternoon tv is now a movie that isn't really good enough to be in theaters .
# ERROR (pos classed as neg %0.2f): richard gere and diane lane put in fine performances as does french actor oliver martinez .
# ERROR (neg classed as pos %0.2f): more trifle than triumph .
# ERROR (pos classed as neg %0.2f): the color sense of stuart little 2 is its most immediate and most obvious pleasure , but it would count for very little if the movie weren't as beautifully shaped and as delicately calibrated in tone as it is .
# ERROR (pos classed as neg %0.2f): a movie where story is almost an afterthought amidst a swirl of colors and inexplicable events .
# ERROR (neg classed as pos %0.2f): piccoli's performance is amazing , yes , but the symbols of loss and denial and life-at-arm's-length in the film seem irritatingly transparent .
# ERROR (pos classed as neg %0.2f): it celebrates the group's playful spark of nonconformity , glancing vividly back at what hibiscus grandly called his 'angels of light . '
# ERROR (pos classed as neg %0.2f): guaranteed to move anyone who ever shook , rattled , or rolled .
# ERROR (pos classed as neg %0.2f): compulsively watchable , no matter how degraded things get .
# ERROR (pos classed as neg %0.2f): the byplay and bickering between the now spy-savvy siblings , carmen ( vega ) and juni ( sabara ) cortez , anchor the film in a very real and amusing give-and-take .
# ERROR (pos classed as neg %0.2f): roman coppola may never become the filmmaker his dad was , but heck  few filmmakers will . but based on cq , i'll certainly be keeping an eye out for his next project .
# ERROR (pos classed as neg %0.2f): the diversity of the artists represented , both in terms of style and ethnicity , prevents the proceedings from feeling repetitious , as does the appropriately brief 40-minute running time .
# ERROR (pos classed as neg %0.2f): it's one heck of a character study -- not of hearst or davies but of the unique relationship between them .
# ERROR (pos classed as neg %0.2f):  . . . the one thing this wild film has that other imax films don't : chimps , lots of chimps , all blown up to the size of a house . that's fun for kids of any age .
# ERROR (neg classed as pos %0.2f): director uwe boll and writer robert dean klein fail to generate any interest in an unsympathetic hero caught up in an intricate plot that while cleverly worked out , cannot overcome blah characters .
# ERROR (neg classed as pos %0.2f): nohe has made a decent 'intro' documentary , but he feels like a spectator and not a participant .
# ERROR (neg classed as pos %0.2f): never comes together as a coherent whole .
# ERROR (neg classed as pos %0.2f): everything is off .
# ERROR (pos classed as neg %0.2f): despite its flaws , secretary stays in your head and makes you question your own firmly held positions .
# ERROR (pos classed as neg %0.2f): my wife's plotting is nothing special ; it's the delivery that matters here .
# ERROR (pos classed as neg %0.2f): you won't have any trouble getting kids to eat up these veggies .
# ERROR (pos classed as neg %0.2f): the spaniel-eyed jean reno infuses hubert with a mixture of deadpan cool , wry humor and just the measure of tenderness required to give this comic slugfest some heart .
# ERROR (pos classed as neg %0.2f): the weakest of the four harry potter books has been transformed into the stronger of the two films by the thinnest of margins .
# ERROR (neg classed as pos %0.2f): kapur's contradictory feelings about his material result in a movie that works against itself .
# ERROR (pos classed as neg %0.2f): the beauty of alexander payne's ode to the everyman is in the details .
# ERROR (pos classed as neg %0.2f): if you don't flee , you might be seduced . if you don't laugh , flee .
# ERROR (neg classed as pos %0.2f): plods along , minus the twisted humor and eye-popping visuals that have made miike . . . a cult hero .
# ERROR (neg classed as pos %0.2f): it's probably not easy to make such a worthless film . . .
# ERROR (neg classed as pos %0.2f): this one is certainly well-meaning , but it's also simple-minded and contrived .
# ERROR (pos classed as neg %0.2f): a romantic comedy , yes , but one with characters who think and talk about their goals , and are working on hard decisions .
# ERROR (pos classed as neg %0.2f): that rare film whose real-life basis is , in fact , so interesting that no embellishment is needed .
# ERROR (pos classed as neg %0.2f): a jewish ww ii doc that isn't trying simply to out-shock , out-outrage or out-depress its potential audience ! who knew . . .
# ERROR (pos classed as neg %0.2f): tully is worth a look for its true-to-life characters , its sensitive acting , its unadorned view of rural life and the subtle direction of first-timer hilary birmingham .
# ERROR (pos classed as neg %0.2f): a movie for 11-year-old boys with sports dreams of their own and the preteen girls who worship lil' bow wow .
# ERROR (pos classed as neg %0.2f): high crimes knows the mistakes that bad movies make and is determined not to make them , and maybe that is nobility of a sort .
# ERROR (pos classed as neg %0.2f): while maintaining the appearance of clinical objectivity , this sad , occasionally horrifying but often inspiring film is among wiseman's warmest .
# ERROR (neg classed as pos %0.2f): leaks treacle from every pore .
# ERROR (neg classed as pos %0.2f): a frustrating combination of strained humor and heavy-handed sentimentality .
# ERROR (pos classed as neg %0.2f): it's predictable , but it jumps through the expected hoops with style and even some depth .
# ERROR (pos classed as neg %0.2f): there's no reason to miss interview with the assassin
# ERROR (pos classed as neg %0.2f): there is little question that this is a serious work by an important director who has something new to say about how , in the flip-flop of courtship , we often reel in when we should be playing out .
# ERROR (pos classed as neg %0.2f): like its new england characters , most of whom wander about in thick clouds of denial , the movie eventually gets around to its real emotional business , striking deep chords of sadness .
# ERROR (neg classed as pos %0.2f): a well acted and well intentioned snoozer .
# ERROR (neg classed as pos %0.2f): leaves viewers out in the cold and undermines some phenomenal performances .
# ERROR (neg classed as pos %0.2f): 'yes , that's right : it's forrest gump , angel of death . '
# ERROR (neg classed as pos %0.2f): the problem with the bread , my sweet is that it's far too sentimental .
# ERROR (pos classed as neg %0.2f): the film provides some great insight into the neurotic mindset of all comics -- even those who have reached the absolute top of the game .
# ERROR (pos classed as neg %0.2f): what could have easily become a cold , calculated exercise in postmodern pastiche winds up a powerful and deeply moving example of melodramatic moviemaking .
# ERROR (neg classed as pos %0.2f): message movie or an action-packed submarine spectacular ? alas , it's neither .
# ERROR (pos classed as neg %0.2f): there are problems with this film that even 3 oscar winners can't overcome , but it's a nice girl-buddy movie once it gets rock-n-rolling .
# ERROR (neg classed as pos %0.2f):  . . . too dull to enjoy .
# ERROR (pos classed as neg %0.2f): the film's strength isn't in its details , but in the larger picture it paints - of a culture in conflict with itself , with the thin veneer of nationalism that covers our deepest , media-soaked fears .
# ERROR (pos classed as neg %0.2f):  . . . a delicious crime drama on par with the slickest of mamet .
# ERROR (neg classed as pos %0.2f): more successful at relating history than in creating an emotionally complex , dramatically satisfying heroine
# ERROR (pos classed as neg %0.2f): a compassionate , moving portrait of an american ( and an america ) always reaching for something just outside his grasp .
# ERROR (pos classed as neg %0.2f): in an era where big stars and high production values are standard procedure , narc strikes a defiantly retro chord , and outpaces its contemporaries with daring and verve .
# ERROR (pos classed as neg %0.2f): even if the ride's a little bumpy , with a final lap that's all too suspiciously smooth , you gotta give director roger michell , best known for the superfluous notting hill , credit for trying .
# ERROR (pos classed as neg %0.2f): there has been much puzzlement among critics about what the election symbolizes . i believe the message is in the messenger : the agent is a woman .
# ERROR (pos classed as neg %0.2f): full frontal is the antidote for soderbergh fans who think he's gone too commercial since his two oscar nominated films in 2000
# ERROR (neg classed as pos %0.2f): while certain cues , like the happy music , suggest that this movie is supposed to warm our hearts , jeong-hyang lee's film is just as likely to blacken that organ with cold vengefulness .
# ERROR (pos classed as neg %0.2f): family portrait of need , neurosis and nervy negativity is a rare treat that shows the promise of digital filmmaking .
# ERROR (neg classed as pos %0.2f): scotland , pa is entirely too straight-faced to transcend its clever concept .
# ERROR (neg classed as pos %0.2f): it's not a bad plot ; but , unfortunately , the movie is nowhere near as refined as all the classic dramas it borrows from .
# ERROR (pos classed as neg %0.2f): just about the surest bet for an all-around good time at the movies this summer .
# ERROR (pos classed as neg %0.2f): you might not buy the ideas . but you'll definitely want the t-shirt .
# ERROR (pos classed as neg %0.2f): tsai ming-liang's witty , wistful new film , what time is it there ? , is a temporal inquiry that shoulders its philosophical burden lightly .
# ERROR (pos classed as neg %0.2f): much of all about lily chou-chou is mesmerizing : some of its plaintiveness could make you weep .
# ERROR (pos classed as neg %0.2f): what really makes it special is that it pulls us into its world , gives us a hero whose suffering and triumphs we can share , surrounds him with interesting characters and sends us out of the theater feeling we've shared a great adventure .
# ERROR (neg classed as pos %0.2f): blessed with immense physical prowess he may well be , but ahola is simply not an actor . and in truth , cruel as it may sound , he makes arnold schwarzenegger look like spencer tracy .
# ERROR (pos classed as neg %0.2f): he's the scariest guy you'll see all summer .
# ERROR (pos classed as neg %0.2f): unfolds with such a wallop of you-are-there immediacy that when the bullets start to fly , your first instinct is to duck .
# ERROR (neg classed as pos %0.2f): not at all clear what it's trying to say and even if it were  i doubt it would be all that interesting .
# ERROR (pos classed as neg %0.2f): a sports movie with action that's exciting on the field and a story you care about off it .
# ERROR (pos classed as neg %0.2f): director david jacobson gives dahmer a consideration that the murderer never game his victims .
# ERROR (pos classed as neg %0.2f): the story is virtually impossible to follow here , but there's a certain style and wit to the dialogue .
# ERROR (pos classed as neg %0.2f): the most compelling performance of the year adds substantial depth to this shocking testament to anti-semitism and neo-fascism .
# ERROR (neg classed as pos %0.2f): it treats women like idiots .
# ERROR (pos classed as neg %0.2f): the movie occasionally threatens to become didactic , but it's too grounded in the reality of its characters to go over the edge . a touch of humor or an unexpected plot twist always pulls it back .
# ERROR (neg classed as pos %0.2f): a manipulative feminist empowerment tale thinly posing as a serious drama about spousal abuse .
# ERROR (pos classed as neg %0.2f): undoubtedly the scariest movie ever made about tattoos .
# ERROR (neg classed as pos %0.2f): eastwood is an icon of moviemaking , one of the best actors , directors and producers around , responsible for some excellent work . but even a hero can stumble sometimes .
# ERROR (pos classed as neg %0.2f): unlike the speedy wham-bam effect of most hollywood offerings , character development -- and more importantly , character empathy -- is at the heart of italian for beginners .
# ERROR (neg classed as pos %0.2f): another big , dumb action movie in the vein of xxx , the transporter is riddled with plot holes big enough for its titular hero to drive his sleek black bmw through .
# ERROR (pos classed as neg %0.2f): the hook is the drama within the drama , as an unsolved murder and an unresolved moral conflict jockey for the spotlight .
# ERROR (neg classed as pos %0.2f): sensitive though not quite revelatory documentary .
# ERROR (pos classed as neg %0.2f): a hypnotic portrait of this sad , compulsive life .
# ERROR (pos classed as neg %0.2f): once the downward spiral comes to pass , auto focus bears out as your typical junkie opera . . .
# ERROR (pos classed as neg %0.2f): writer/director walter hill is in his hypermasculine element here , once again able to inject some real vitality and even art into a pulpy concept that , in many other hands would be completely forgettable .
# ERROR (pos classed as neg %0.2f): if you haven't seen the film lately , you may be surprised at the variety of tones in spielberg's work . much of it is funny , but there are also some startling , surrealistic moments . . .
# ERROR (neg classed as pos %0.2f): thoroughly awful .
# ERROR (pos classed as neg %0.2f): twenty years later , e . t . is still a cinematic touchstone .
# ERROR (pos classed as neg %0.2f): drug abuse , infidelity and death aren't usually comedy fare , but turpin's film allows us to chuckle through the angst .
# ERROR (pos classed as neg %0.2f): the last kiss will probably never achieve the popularity of my big fat greek wedding , but its provocative central wedding sequence has far more impact .
# ERROR (pos classed as neg %0.2f): a gripping , searing portrait of a lost soul trying to find her way through life .
# ERROR (neg classed as pos %0.2f): despite some strong performances , never rises above the level of a telanovela .
# ERROR (pos classed as neg %0.2f): it's a demented kitsch mess ( although the smeary digital video does match the muddled narrative ) , but it's savvy about celebrity and has more guts and energy than much of what will open this year .
# ERROR (pos classed as neg %0.2f): if the man from elysian fields is doomed by its smallness , it is also elevated by it--the kind of movie that you enjoy more because you're one of the lucky few who sought it out .
# ERROR (pos classed as neg %0.2f): lasker's canny , meditative script distances sex and love , as byron and luther . . . realize they can't get no satisfaction without the latter .
# ERROR (pos classed as neg %0.2f): a miniscule little bleep on the film radar , but one that many more people should check out
# ERROR (pos classed as neg %0.2f): 'they' begins and ends with scenes so terrifying i'm still stunned . and i've decided to leave a light on every night from now on .
# ERROR (pos classed as neg %0.2f): this is such a high-energy movie where the drumming and the marching are so excellent , who cares if the story's a little weak .
# ERROR (pos classed as neg %0.2f):  " simone " is a fun and funky look into an artificial creation in a world that thrives on artificiality .
# ERROR (pos classed as neg %0.2f): using his audience as a figurative port-of-call , dong pulls his even-handed ideological ship to their dock for unloading , before he continues his longer journey still ahead .
# ERROR (pos classed as neg %0.2f): thankfully , the film , which skirts that rapidly deteriorating line between fantasy and reality . . . takes a tongue-in-cheek attitude even as it pushes the croc hunter agenda .
# ERROR (pos classed as neg %0.2f): this engrossing , characteristically complex tom clancy thriller is shifty in the manner in which it addresses current terrorism anxieties and sidesteps them at the same time .
# ERROR (pos classed as neg %0.2f): if you ever wondered what it would be like to be smack in the middle of a war zone armed with nothing but a camera , this oscar-nominated documentary takes you there .
# ERROR (pos classed as neg %0.2f): it's a rollicking adventure for you and all your mateys , regardless of their ages .
# ERROR (pos classed as neg %0.2f): could this be the first major studio production shot on video tape instead of film ?
# ERROR (neg classed as pos %0.2f):  . . . stale and uninspired .
# ERROR (neg classed as pos %0.2f): this is not the undisputed worst boxing movie ever , but it's certainly not a champion - the big loser is the audience .
# ERROR (pos classed as neg %0.2f): goldmember is funny enough to justify the embarrassment of bringing a barf bag to the moviehouse .
# ERROR (neg classed as pos %0.2f): a showcase for both the scenic splendor of the mountains and for legendary actor michel serrault , the film is less successful on other levels .
# ERROR (pos classed as neg %0.2f): impossible as it may sound , this film's heart is even more embracing than monty , if only because it accepts nasty behavior and severe flaws as part of the human condition .
# ERROR (neg classed as pos %0.2f): the stunt work is top-notch ; the dialogue and drama often food-spittingly funny .
# ERROR (pos classed as neg %0.2f): the cast . . . keeps this pretty watchable , and casting mick jagger as director of the escort service was inspired .
# ERROR (neg classed as pos %0.2f): a 94-minute travesty of unparalleled proportions , writer-director parker seems to go out of his way to turn the legendary wit's classic mistaken identity farce into brutally labored and unfunny hokum .
# ERROR (pos classed as neg %0.2f): this film seems thirsty for reflection , itself taking on adolescent qualities .
# ERROR (neg classed as pos %0.2f): two-bit potboiler .
# ERROR (pos classed as neg %0.2f): a smart and funny , albeit sometimes superficial , cautionary tale of a technology in search of an artist .
# ERROR (pos classed as neg %0.2f):  " frailty " has been written so well , that even a simple " goddammit ! " near the end takes on a whole other meaning .
# ERROR (pos classed as neg %0.2f): the sundance film festival has become so buzz-obsessed that fans and producers descend upon utah each january to ferret out the next great thing . 'tadpole' was one of the films so declared this year , but it's really more of the next pretty good thing .
# ERROR (pos classed as neg %0.2f): robert harmon's less-is-more approach delivers real bump-in -the-night chills -- his greatest triumph is keeping the creepy crawlies hidden in the film's thick shadows .
# ERROR (neg classed as pos %0.2f): the rules of attraction gets us too drunk on the party favors to sober us up with the transparent attempts at moralizing .
# ERROR (neg classed as pos %0.2f): 'wouldn't it be nice if all guys got a taste of what it's like on the other side of the bra ? '
# ERROR (pos classed as neg %0.2f): the story itself it mostly told through on-camera interviews with several survivors , whose riveting memories are rendered with such clarity that it's as if it all happened only yesterday .
# ERROR (pos classed as neg %0.2f): a different movie -- sometimes tedious -- by a director many viewers would like to skip but film buffs should get to know .
# ERROR (pos classed as neg %0.2f): the moral shrapnel and mental shellshock will linger long after this film has ended .
# ERROR (pos classed as neg %0.2f): mr . clooney , mr . kaufman and all their collaborators are entitled to take a deep bow for fashioning an engrossing entertainment out of an almost sure-fire prescription for a critical and commercial disaster .
# ERROR (neg classed as pos %0.2f): the issue of faith is not explored very deeply
# ERROR (pos classed as neg %0.2f): the far future may be awesome to consider , but from period detail to matters of the heart , this film is most transporting when it stays put in the past .
# ERROR (neg classed as pos %0.2f): it all seemed wasted like deniro's once promising career and the once grand long beach boardwalk .
# ERROR (pos classed as neg %0.2f): thanks to a small star with big heart , this family film sequel is plenty of fun for all .
# ERROR (neg classed as pos %0.2f): a waterlogged version of 'fatal attraction' for the teeny-bopper set . . . a sad , soggy potboiler that wastes the talents of its attractive young leads .
# ERROR (neg classed as pos %0.2f): too close to phantom menace for comfort .
# ERROR (neg classed as pos %0.2f): too stagey , talky -- and long -- for its own good .
# ERROR (pos classed as neg %0.2f): it never fails to engage us .
# ERROR (neg classed as pos %0.2f): the characters are interesting and the relationship between yosuke and saeko is worth watching as it develops , but there's not enough to the story to fill two hours .
# ERROR (neg classed as pos %0.2f): the boys' sparring , like the succession of blows dumped on guei , wears down the story's more cerebral , and likable , plot elements .
# ERROR (pos classed as neg %0.2f): it's made with deftly unsettling genre flair .
# ERROR (pos classed as neg %0.2f): the reason to see " sade " lay with the chemistry and complex relationship between the marquis ( auteil ) and emilie ( le besco ) .
# ERROR (pos classed as neg %0.2f): while tattoo borrows heavily from both seven and the silence of the lambs , it manages to maintain both a level of sophisticated intrigue and human-scale characters that suck the audience in .
# ERROR (pos classed as neg %0.2f): nearly surreal , dabbling in french , this is no simple movie , and you'll be taking a risk if you choose to see it . i enjoyed the ride ( bumps and all ) , creamy depth , and ultimate theme .
# ERROR (pos classed as neg %0.2f): the acting in pauline and paulette is good all round , but what really sets the film apart is debrauwer's refusal to push the easy emotional buttons .
# ERROR (neg classed as pos %0.2f): mostly , shafer and co-writer gregory hinton lack a strong-minded viewpoint , or a sense of humor .
# ERROR (pos classed as neg %0.2f): my big fat greek wedding is that rare animal known as 'a perfect family film , ' because it's about family .
# ERROR (pos classed as neg %0.2f): corny , schmaltzy and predictable , but still manages to be kind of heartwarming , nonetheless . it's the perfect kind of film to see when you don't want to use your brain . at all .
# ERROR (neg classed as pos %0.2f): a film that will be best appreciated by those willing to endure its extremely languorous rhythms , waiting for happiness is ultimately thoughtful without having much dramatic impact .
# ERROR (pos classed as neg %0.2f): the real charm of this trifle is the deadpan comic face of its star , jean reno , who resembles sly stallone in a hot sake half-sleep .
# ERROR (pos classed as neg %0.2f): dark and unrepentant , this excursion into the epicenter of percolating mental instability is not easily dismissed or forgotten .
# ERROR (neg classed as pos %0.2f): what an embarrassment .
# ERROR (pos classed as neg %0.2f): as an introduction to the man's theories and influence , derrida is all but useless ; as a portrait of the artist as an endlessly inquisitive old man , however , it's invaluable .
# ERROR (pos classed as neg %0.2f): a well-done film of a self-reflexive , philosophical nature .
# ERROR (pos classed as neg %0.2f): it seems impossible that an epic four-hour indian musical about a cricket game could be this good , but it is .
# ERROR (pos classed as neg %0.2f): nothing's at stake , just a twisty double-cross you can smell a mile away--still , the derivative nine queens is lots of fun .
# ERROR (pos classed as neg %0.2f): stephen earnhart's homespun documentary mule skinner blues has nothing but love for its posse of trailer park denizens .
# ERROR (pos classed as neg %0.2f): while mcfarlane's animation lifts the film firmly above the level of other coming-of-age films . . . it's also so jarring that it's hard to get back into the boys' story .
# ERROR (pos classed as neg %0.2f): sad to say -- it accurately reflects the rage and alienation that fuels the self-destructiveness of many young people .
# ERROR (pos classed as neg %0.2f): very amusing , not the usual route in a thriller , and the performances are odd and pixilated and sometimes both .
# ERROR (neg classed as pos %0.2f): the premise of " abandon " holds promise , . . . but its delivery is a complete mess .
# ERROR (neg classed as pos %0.2f): a little too pat for its own good .
# ERROR (pos classed as neg %0.2f): at nearly three hours , the whole of safe conduct is less than the sum of its parts .
# ERROR (pos classed as neg %0.2f): niccol the filmmaker merges his collaborators' symbolic images with his words , insinuating , for example , that in hollywood , only god speaks to the press
# ERROR (pos classed as neg %0.2f): the film's best trick is the way that it treats conspiracy as a kind of political blair witch , a monstrous murk that haunts us precisely because it can never be seen .
# ERROR (pos classed as neg %0.2f): the fact is that the screen is most alive when it seems most likely that broomfield's interviewees , or even himself , will not be for much longer .
# ERROR (pos classed as neg %0.2f): a brutally dry satire of middle american numbness .
# ERROR (neg classed as pos %0.2f):  . . . post-september 11 , " the sum of all fears " seems more tacky and reprehensible , manipulating our collective fear without bestowing the subject with the intelligence or sincerity it unequivocally deserves .
# ERROR (pos classed as neg %0.2f): even if the ring has a familiar ring , it's still unusually crafty and intelligent for hollywood horror .
# ERROR (neg classed as pos %0.2f): soderbergh seems capable only of delivering artfully lighted , earnest inquiries that lack the kind of genuine depth that would make them redeemable .
# ERROR (pos classed as neg %0.2f): it says a lot about a filmmaker when he can be wacky without clobbering the audience over the head and still maintain a sense of urgency and suspense .
# ERROR (pos classed as neg %0.2f): the attraction between these two marginal characters is complex from the start -- and , refreshingly , stays that way .
# ERROR (pos classed as neg %0.2f): a highly personal look at the effects of living a dysfunctionally privileged lifestyle , and by the end , we only wish we could have spent more time in its world .
# ERROR (pos classed as neg %0.2f): the filmmakers try to balance pointed , often incisive satire and unabashed sweetness , with results that are sometimes bracing , sometimes baffling and quite often , and in unexpected ways , touching .
# ERROR (pos classed as neg %0.2f): with so many bad romances out there , this is the kind of movie that deserves a chance to shine .
# ERROR (neg classed as pos %0.2f): it is , by conventional standards , a fairly terrible movie . . . but it is also weirdly fascinating , a ready-made eurotrash cult object . it is also , at times , curiously moving .
# ERROR (pos classed as neg %0.2f): return to never land may be another shameless attempt by disney to rake in dough from baby boomer families , but it's not half-bad .
# ERROR (pos classed as neg %0.2f): a brilliant , absurd collection of vignettes that , in their own idiosyncratic way , sum up the strange horror of life in the new millennium .
# ERROR (pos classed as neg %0.2f): it is a kickass , dense sci-fi action thriller hybrid that delivers and then some . i haven't seen one in so long , no wonder i didn't recognize it at first .
# ERROR (pos classed as neg %0.2f): director juan jose campanella could have turned this into an argentine retread of " iris " or " american beauty , " but instead pulls a little from each film and creates something more beautiful than either of those films .
# ERROR (pos classed as neg %0.2f): funny , somber , absurd , and , finally , achingly sad , bartleby is a fine , understated piece of filmmaking .
# ERROR (neg classed as pos %0.2f): an often unfunny romp .
# ERROR (neg classed as pos %0.2f): the best drug addition movies are usually depressing but rewarding . quitting , however , manages just to be depressing , as the lead actor phones in his autobiographical performance .
# ERROR (pos classed as neg %0.2f): craig bartlett and director tuck tucker should be commended for illustrating the merits of fighting hard for something that really matters .
# ERROR (pos classed as neg %0.2f): kinnear and dafoe give what may be the performances of their careers .
# ERROR (pos classed as neg %0.2f): i stopped thinking about how good it all was , and started doing nothing but reacting to it - feeling a part of its grand locations , thinking urgently as the protagonists struggled , feeling at the mercy of its inventiveness , gasping at its visual delights .
# ERROR (pos classed as neg %0.2f): every individual will see the movie through the prism of his or her own beliefs and prejudices , but the one thing most will take away is the sense that peace is possible . that , in itself , is extraordinary .
# ERROR (pos classed as neg %0.2f): cantet beautifully illuminates what it means sometimes to be inside looking out , and at other times outside looking in .
# ERROR (pos classed as neg %0.2f): sandra nettelbeck beautifully orchestrates the transformation of the chilly , neurotic , and self-absorbed martha as her heart begins to open .
# ERROR (pos classed as neg %0.2f): has a plot full of twists upon knots . . . and a nonstop parade of mock-tarantino scuzbag types that starts out clever but veers into overkill .
# ERROR (neg classed as pos %0.2f): loud , chaotic and largely unfunny .
# ERROR (pos classed as neg %0.2f): the script by david koepp is perfectly serviceable and because he gives the story some soul . . . he elevates the experience to a more mythic level .
# ERROR (neg classed as pos %0.2f): an overstylized , puréed mélange of sex , psychology , drugs and philosophy . sometimes entertaining , sometimes indulgent -- but never less than pure wankery .
# ERROR (neg classed as pos %0.2f): a less-than-thrilling thriller .
# ERROR (pos classed as neg %0.2f): you may think you have figured out the con and the players in this debut film by argentine director fabian bielinsky , but while you were thinking someone made off with your wallet .
# ERROR (neg classed as pos %0.2f): innocuous enough to make even jean-claude van damme look good .
# ERROR (neg classed as pos %0.2f): an intermittently pleasing but mostly routine effort .
# ERROR (neg classed as pos %0.2f): a family-friendly fantasy that ends up doing very little with its imaginative premise .
# ERROR (pos classed as neg %0.2f): to some eyes this will seem like a recycling of clichés , an assassin's greatest hits . to others , it will remind them that hong kong action cinema is still alive and kicking .
# ERROR (neg classed as pos %0.2f): watching trouble every day , at least if you don't know what's coming , is like biting into what looks like a juicy , delicious plum on a hot summer day and coming away with your mouth full of rotten pulp and living worms .
# ERROR (pos classed as neg %0.2f): spider-man is about growing strange hairs , getting a more mature body , and finding it necessary to hide new secretions from the parental units .
# ERROR (neg classed as pos %0.2f): routine and rather silly .
# ERROR (neg classed as pos %0.2f): less a study in madness or love than a study in schoolgirl obsession .
# ERROR (pos classed as neg %0.2f): 'enigma' is the kind of engaging historical drama that hollywood appears to have given up on in favor of sentimental war movies in the vein of 'we were soldiers . '
# ERROR (neg classed as pos %0.2f): 'the war of the roses , ' trailer-trash style . entertaining but like shooting fish in a barrel .
# ERROR (pos classed as neg %0.2f): others , more attuned to the anarchist maxim that 'the urge to destroy is also a creative urge' , or more willing to see with their own eyes , will find morrison's iconoclastic uses of technology to be liberating .
# ERROR (neg classed as pos %0.2f): it should be interesting , it should be poignant , it turns out to be affected and boring .
# ERROR (neg classed as pos %0.2f): this is amusing for about three minutes .
# ERROR (pos classed as neg %0.2f): there are no special effects , and no hollywood endings .
# ERROR (pos classed as neg %0.2f): reveals how important our special talents can be when put in service of of others . it also shows how deeply felt emotions can draw people together across the walls that might otherwise separate them .
# ERROR (pos classed as neg %0.2f): ultimately , the message of trouble every day seems to be that all sexual desire disrupts life's stasis .
# ERROR (pos classed as neg %0.2f): brims with passion : for words , for its eccentric , accident-prone characters , and for the crazy things that keep people going in this crazy life .
# ERROR (pos classed as neg %0.2f): a deliciously mordant , bitter black comedy .
# ERROR (pos classed as neg %0.2f): macdowell . . . gives give a solid , anguished performance that eclipses nearly everything else she's ever done .
# ERROR (pos classed as neg %0.2f): absorbing and disturbing -- perhaps more disturbing than originally intended -- but a little clarity would have gone a long way .
# ERROR (neg classed as pos %0.2f):  . . . generically , forgettably pleasant from start to finish .
# ERROR (pos classed as neg %0.2f): the last scenes of the film are anguished , bitter and truthful . mr . koshashvili is a director to watch .
# ERROR (pos classed as neg %0.2f): writer-director david jacobson and his star , jeremy renner , have made a remarkable film that explores the monster's psychology not in order to excuse him but rather to demonstrate that his pathology evolved from human impulses that grew hideously twisted .
# ERROR (neg classed as pos %0.2f): as is often the case with ambitious , eager first-time filmmakers , mr . murray , a prolific director of music videos , stuffs his debut with more plot than it can comfortably hold .
# ERROR (pos classed as neg %0.2f): director kapur is a filmmaker with a real flair for epic landscapes and adventure , and this is a better film than his earlier english-language movie , the overpraised elizabeth .
# ERROR (neg classed as pos %0.2f): the first fatal attraction was vile enough . do we really need the tiger beat version ?
# ERROR (pos classed as neg %0.2f): an impossible romance , but we root for the patronized iranian lad .
# ERROR (neg classed as pos %0.2f): unspools like a highbrow , low-key , 102-minute infomercial , blending entrepreneurial zeal with the testimony of satisfied customers .
# ERROR (pos classed as neg %0.2f): a fascinating glimpse into an insular world that gives the lie to many clichés and showcases a group of dedicated artists .
# ERROR (neg classed as pos %0.2f): the film meant well in its horse tale about freedom , but wasn't able to reach the heart because it was too overbearing .
# ERROR (neg classed as pos %0.2f): feels less like a change in [herzog's] personal policy than a half-hearted fluke .
# ERROR (neg classed as pos %0.2f): do not see this film .
# ERROR (neg classed as pos %0.2f): not just unlikable . disturbing . disgusting . without any redeeming value whatsoever .
# ERROR (pos classed as neg %0.2f): brosnan is more feral in this film than i've seen him before and halle berry does her best to keep up with him .
# ERROR (neg classed as pos %0.2f): stale , futile scenario .
# ERROR (pos classed as neg %0.2f): take care is nicely performed by a quintet of actresses , but nonetheless it drags during its 112-minute length .
# ERROR (pos classed as neg %0.2f):  . . . a joke at once flaky and resonant , lightweight and bizarrely original .
# ERROR (pos classed as neg %0.2f): one of the most exciting action films to come out of china in recent years .
# ERROR (pos classed as neg %0.2f): i'll put it this way : if you're in the mood for a melodrama narrated by talking fish , this is the movie for you .
# ERROR (neg classed as pos %0.2f): the movie is a little tired ; maybe the original inspiration has run its course .
# ERROR (pos classed as neg %0.2f): it helps that lil bow wow . . . tones down his pint-sized gangsta act to play someone who resembles a real kid .
# ERROR (pos classed as neg %0.2f): engagingly captures the maddening and magnetic ebb and flow of friendship .
# ERROR (neg classed as pos %0.2f): frenetic but not really funny .
# ERROR (pos classed as neg %0.2f): this english-language version . . . does full honor to miyazaki's teeming and often unsettling landscape , and to the conflicted complexity of his characters .
# ERROR (pos classed as neg %0.2f): in the pianist , polanski is saying what he has long wanted to say , confronting the roots of his own preoccupations and obsessions , and he allows nothing to get in the way .
# ERROR (pos classed as neg %0.2f): art-house to the core , read my lips is a genre-curling crime story that revives the free-wheeling noir spirit of old french cinema .
# ERROR (neg classed as pos %0.2f): though there are entertaining and audacious moments , the movie's wildly careening tone and an extremely flat lead performance do little to salvage this filmmaker's flailing reputation .
# ERROR (pos classed as neg %0.2f): [gai] comes closer to any actress i can remember to personifying independence in its purest and , yes , most intimidating form .
# ERROR (pos classed as neg %0.2f): those outside show business will enjoy a close look at people they don't really want to know .
# ERROR (pos classed as neg %0.2f): filmmakers dana janklowicz-mann and amir mann area headed east , far east , in retelling a historically significant , and personal , episode detailing how one international city welcomed tens of thousands of german jewish refugees while the world's democracie
# ERROR (pos classed as neg %0.2f): the heart of the film is a touching reflection on aging , suffering and the prospect of death .
# ERROR (pos classed as neg %0.2f): pray has really done his subject justice .
# ERROR (neg classed as pos %0.2f): it's best to avoid imprisonment with the dull , nerdy folks that inhabit cherish .
# ERROR (neg classed as pos %0.2f): who needs love like this ?
# ERROR (pos classed as neg %0.2f): it's a drawling , slobbering , lovable run-on sentence of a film , a southern gothic with the emotional arc of its raw blues soundtrack .
# ERROR (pos classed as neg %0.2f): some body will take you places you haven't been , and also places you have .
# ERROR (pos classed as neg %0.2f): the movie is . . . very funny as you peek at it through the fingers in front of your eyes .
# ERROR (pos classed as neg %0.2f): woody allen's latest is an ambling , broad comedy about all there is to love -- and hate -- about the movie biz .
# ERROR (neg classed as pos %0.2f): the character of zigzag is not sufficiently developed to support a film constructed around him .
# ERROR (pos classed as neg %0.2f): star/producer salma hayek and director julie taymor have infused frida with a visual style unique and inherent to the titular character's paintings and in the process created a masterful work of art of their own .
# ERROR (pos classed as neg %0.2f): a powerful and telling story that examines forbidden love , racial tension , and other issues that are as valid today as they were in the 1950s .
# ERROR (neg classed as pos %0.2f): the sinister inspiration that fuelled devito's early work is confused in death to smoochy into something both ugly and mindless .
# ERROR (neg classed as pos %0.2f): technically and artistically inept .
# ERROR (neg classed as pos %0.2f): goldbacher draws on an elegant visual sense and a talent for easy , seductive pacing . . . but she and writing partner laurence coriat don't manage an equally assured narrative coinage .
# ERROR (pos classed as neg %0.2f): it lets you brush up against the humanity of a psycho , without making him any less psycho .
# ERROR (pos classed as neg %0.2f): the comic performances are all spot on , especially lee ross's turn as ken .
# ERROR (pos classed as neg %0.2f): a sweet-tempered comedy that forgoes the knee-jerk misogyny that passes for humor in so many teenage comedies .
# ERROR (neg classed as pos %0.2f): it's so crammed with scenes and vistas and pretty moments that it's left a few crucial things out , like character development and coherence .
# ERROR (pos classed as neg %0.2f): the film may appear naked in its narrative form . . . but it goes deeper than that , to fundamental choices that include the complexity of the catholic doctrine
# ERROR (pos classed as neg %0.2f): nair and writer laura cahill dare to build a movie around some flawed but rather unexceptional women , emerging with a fine character study that's short on plot but rich in the tiny revelations of real life .
# ERROR (pos classed as neg %0.2f): a dark , quirky road movie that constantly defies expectation .
# ERROR (pos classed as neg %0.2f): it's rare to find a film that dazzles the eye , challenges the brain , and satisfies our lust for fast-paced action , but minority report delivers all that and a whole lot more .
# ERROR (neg classed as pos %0.2f): an awkward and indigestible movie .
# ERROR (pos classed as neg %0.2f): an involving true story of a chinese actor who takes up drugs and winds up in an institution--acted mostly by the actual people involved .
# ERROR (neg classed as pos %0.2f): so-so entertainment .
# ERROR (pos classed as neg %0.2f): predictable storyline and by-the-book scripting is all but washed away by sumptuous ocean visuals and the cinematic stylings of director john stockwell .
# ERROR (neg classed as pos %0.2f): a clumsily manufactured exploitation flick , a style-free exercise in manipulation and mayhem .
# ERROR (pos classed as neg %0.2f): with we were soldiers , hollywood makes a valiant attempt to tell a story about the vietnam war before the pathology set in .
# ERROR (pos classed as neg %0.2f): with its hint of an awkward hitchcockian theme in tact , harmon's daunting narrative promotes a reasonable landscape of conflict and pathos to support the scattershot terrorizing tone
# ERROR (pos classed as neg %0.2f): exposing the ways we fool ourselves is one hour photo's real strength .
# ERROR (pos classed as neg %0.2f): jolie gives it that extra little something that makes it worth checking out at theaters , especially if you're in the mood for something more comfortable than challenging .
# ERROR (pos classed as neg %0.2f): suspend your disbelief here and now , or you'll be shaking your head all the way to the credits .
# ERROR (neg classed as pos %0.2f): at some point , all this visual trickery stops being clever and devolves into flashy , vaguely silly overkill .
# ERROR (pos classed as neg %0.2f): about schmidt belongs to nicholson . gone are the flamboyant mannerisms that are the trademark of several of his performances . as schmidt , nicholson walks with a slow , deliberate gait , chooses his words carefully and subdues his natural exuberance .
# ERROR (neg classed as pos %0.2f): cattaneo reworks the formula that made the full monty a smashing success . . . but neglects to add the magic that made it all work .
# ERROR (neg classed as pos %0.2f): koepp's screenplay isn't nearly surprising or clever enough to sustain a reasonable degree of suspense on its own .
# ERROR (pos classed as neg %0.2f): proves mainly that south korean filmmakers can make undemanding action movies with all the alacrity of their hollywood counterparts .
# ERROR (pos classed as neg %0.2f): what " empire " lacks in depth it makes up for with its heart .
# ERROR (pos classed as neg %0.2f): the result is more depressing than liberating , but it's never boring .
# ERROR (pos classed as neg %0.2f): it moves quickly , adroitly , and without fuss ; it doesn't give you time to reflect on the inanity -- and the cold war datedness -- of its premise .
# ERROR (pos classed as neg %0.2f): spielberg has managed to marry science fiction with film noir and action flicks with philosophical inquiry .
# ERROR (pos classed as neg %0.2f): the film's 45-minute running time stops shy of overkill , though viewers may be more exhausted than the athletes onscreen .
# ERROR (pos classed as neg %0.2f): a compelling coming-of-age drama about the arduous journey of a sensitive young girl through a series of foster homes and a fierce struggle to pull free from her dangerous and domineering mother's hold over her .
# ERROR (neg classed as pos %0.2f): wallace directs with such patronising reverence , it turns the stomach .
# ERROR (pos classed as neg %0.2f): the determination of pinochet's victims to seek justice , and their often heartbreaking testimony , spoken directly into director patricio guzman's camera , pack a powerful emotional wallop .
# ERROR (neg classed as pos %0.2f): it gets bogged down by hit-and-miss topical humour before getting to the truly good stuff .
# ERROR (pos classed as neg %0.2f): in addition to gluing you to the edge of your seat , changing lanes is also a film of freshness , imagination and insight .
# ERROR (neg classed as pos %0.2f): an unbelievably stupid film , though occasionally fun enough to make you forget its absurdity .
# ERROR (pos classed as neg %0.2f): while its careful pace and seemingly opaque story may not satisfy every moviegoer's appetite , the film's final scene is soaringly , transparently moving .
# ERROR (pos classed as neg %0.2f): pull[s] off the rare trick of recreating not only the look of a certain era , but also the feel .
# ERROR (pos classed as neg %0.2f): the members manage to pronounce kok exactly as you think they might , thus giving the cast ample opportunity to use that term as often as possible . it's very beavis and butthead , yet always seems to elicit a chuckle .
# ERROR (neg classed as pos %0.2f): authentic , and at times endearing , humorous , spooky , educational , but at other times as bland as a block of snow .
# ERROR (pos classed as neg %0.2f): if the message seems more facile than the earlier films , the images have such a terrible beauty you may not care .
# ERROR (pos classed as neg %0.2f): greg kinnear gives a mesmerizing performance as a full-fledged sex addict who is in complete denial about his obsessive behavior .
# ERROR (pos classed as neg %0.2f): it won't hold up over the long haul , but in the moment , finch's tale provides the forgettable pleasures of a saturday matinee .
# ERROR (neg classed as pos %0.2f): diaz wears out her welcome in her most charmless performance
# ERROR (pos classed as neg %0.2f): with a large cast representing a broad cross-section , tavernier's film bounds along with the rat-a-tat energy of " his girl friday , " maintaining a light touch while tackling serious themes .
# ERROR (pos classed as neg %0.2f): in the director's cut , the film is not only a love song to the movies but it also is more fully an example of the kind of lush , all-enveloping movie experience it rhapsodizes .
# ERROR (pos classed as neg %0.2f): the story , like life , refuses to be simple , and the result is a compelling slice of awkward emotions .
# ERROR (neg classed as pos %0.2f): how do you spell cliché ?
# ERROR (pos classed as neg %0.2f): even if you have no interest in the gang-infested , east-vs . -west coast rap wars , this modern mob music drama never fails to fascinate .
# ERROR (pos classed as neg %0.2f): a film that takes you inside the rhythms of its subject : you experience it as you watch .
# ERROR (neg classed as pos %0.2f): ill-considered , unholy hokum .
# ERROR (neg classed as pos %0.2f): fans of plympton's shorts may marginally enjoy the film , but it is doubtful this listless feature will win him any new viewers .
# ERROR (neg classed as pos %0.2f): a simple , sometimes maddeningly slow film that has just enough charm and good acting to make it interesting , but is ultimately pulled under by the pacing and lack of creativity within .
# ERROR (pos classed as neg %0.2f): while the humor is recognizably plympton , he has actually bothered to construct a real story this time .
# ERROR (neg classed as pos %0.2f): claims to sort the bad guys from the good , which is its essential problem .
# ERROR (neg classed as pos %0.2f): it's not nearly as fresh or enjoyable as its predecessor , but there are enough high points to keep this from being a complete waste of time .
# ERROR (pos classed as neg %0.2f): what might have been readily dismissed as the tiresome rant of an aging filmmaker still thumbing his nose at convention takes a surprising , subtle turn at the midway point .
# ERROR (pos classed as neg %0.2f): take any 12-year-old boy to see this picture , and he'll be your slave for a year .
# ERROR (neg classed as pos %0.2f): even fans of ismail merchant's work , i suspect , would have a hard time sitting through this one .
# ERROR (pos classed as neg %0.2f): pratfalls aside , barbershop gets its greatest play from the timeless spectacle of people really talking to each other .
# ERROR (pos classed as neg %0.2f): a sober and affecting chronicle of the leveling effect of loss .
# ERROR (pos classed as neg %0.2f): light the candles , bring out the cake and don't fret about the calories because there's precious little substance in birthday girl -- it's simply , and surprisingly , a nice , light treat .
# ERROR (pos classed as neg %0.2f): what begins as a conventional thriller evolves into a gorgeously atmospheric meditation on life-changing chance encounters .
# ERROR (neg classed as pos %0.2f): the plan to make enough into an inspiring tale of survival wrapped in the heart-pounding suspense of a stylish psychological thriller' has flopped as surely as a soufflé gone wrong .
# ERROR (pos classed as neg %0.2f): in many ways , reminiscent of 1992's unforgiven which also utilized the scintillating force of its actors to draw out the menace of its sparse dialogue .
# ERROR (pos classed as neg %0.2f): not only does spider-man deliver , but i suspect it might deliver again and again .
# ERROR (pos classed as neg %0.2f): shanghai ghetto , much stranger than any fiction , brings this unknown slice of history affectingly to life .
# ERROR (neg classed as pos %0.2f): and people make fun of me for liking showgirls</> .
# ERROR (pos classed as neg %0.2f): lawrence plumbs personal tragedy and also the human comedy .
# ERROR (pos classed as neg %0.2f): it's hard to imagine anybody ever being " in the mood " to view a movie as harrowing and painful as the grey zone , but it's equally hard to imagine anybody being able to tear their eyes away from the screen once it's started .
# ERROR (neg classed as pos %0.2f): the plot is romantic comedy boilerplate from start to finish .
# ERROR (pos classed as neg %0.2f): bright seems alternately amused and disgusted with this material , and he can't help throwing in a few of his own touches .
# ERROR (neg classed as pos %0.2f): a hit- and-miss affair , consistently amusing but not as outrageous or funny as cho may have intended or as imaginative as one might have hoped .
# ERROR (neg classed as pos %0.2f): earnest and heartfelt but undernourished and plodding .
# ERROR (neg classed as pos %0.2f): makes for a pretty unpleasant viewing experience .
# ERROR (pos classed as neg %0.2f): for those who are intrigued by politics of the '70s , the film is every bit as fascinating as it is flawed .
# ERROR (pos classed as neg %0.2f): those who don't entirely 'get' godard's distinctive discourse will still come away with a sense of his reserved but existential poignancy .
# ERROR (pos classed as neg %0.2f): succeeds where its recent predecessor miserably fails because it demands that you suffer the dreadfulness of war from both sides .
# ERROR (pos classed as neg %0.2f): it's more enjoyable than i expected , though , and that's because the laughs come from fairly basic comedic constructs . cinematic pratfalls given a working over . the cast is spot on and the mood is laid back .
# ERROR (neg classed as pos %0.2f): on the bright side , it contains jesse ventura's best work since the xfl .
# ERROR (pos classed as neg %0.2f): star wars is back in a major way .
# ERROR (pos classed as neg %0.2f): el título no engaña : la película narra una historia donde una mujer enfrentará cierta realidad , y donde el sexo es . . .
# ERROR (pos classed as neg %0.2f): the socio-histo-political treatise is told in earnest strides . . . [and] personal illusion is deconstructed with poignancy .
# ERROR (pos classed as neg %0.2f): there's absolutely no reason why blue crush , a late-summer surfer girl entry , should be as entertaining as it is
# ERROR (pos classed as neg %0.2f): your children will be occupied for 72 minutes .
# ERROR (neg classed as pos %0.2f): not a bad premise , but the execution is lackluster at best .
# ERROR (neg classed as pos %0.2f): its premise is smart , but the execution is pretty weary .
# ERROR (pos classed as neg %0.2f): morton uses her face and her body language to bring us morvern's soul , even though the character is almost completely deadpan .
# ERROR (pos classed as neg %0.2f): moretti's compelling anatomy of grief and the difficult process of adapting to loss .
# ERROR (pos classed as neg %0.2f): graced with the kind of social texture and realism that would be foreign in american teen comedies .
# ERROR (pos classed as neg %0.2f): an indispensable peek at the art and the agony of making people laugh .
# ERROR (neg classed as pos %0.2f): passably entertaining but also mechanical and joyless .
# ERROR (neg classed as pos %0.2f): the movie is almost completely lacking in suspense , surprise and consistent emotional conviction .
# ERROR (neg classed as pos %0.2f): an eccentric little comic/thriller deeply in love with its own quirky personality .
# ERROR (pos classed as neg %0.2f): great fun both for sports aficionados and for ordinary louts whose idea of exercise is climbing the steps of a stadium-seat megaplex .
# ERROR (neg classed as pos %0.2f): elegantly crafted but emotionally cold , a puzzle whose intricate construction one can admire but is difficult to connect with on any deeper level .
# ERROR (pos classed as neg %0.2f): what the film lacks in general focus it makes up for in compassion , as corcuera manages to find the seeds of hope in the form of collective action .
# Sigma: 0.28
# Threshold: -31.44
# Mean score: -16.0
# Accuracy (All)=0.61 (653/1066)
#
# Positive scores..
# Precision (Pos)=0.64 (255/396)
# Recall (Pos)=0.48 (255/527)
# F-measure (Pos)=0.55
# Negative scores..
# Precision (Neg)=0.59 (398/670)
# Recall (Neg)=0.74 (398/539)
# F-measure (Neg)=0.65
#
# Mean scores..
# Precision (Mean)=0.62
# Recall (Mean)=0.61
# F-measure (Mean)=0.60

# %% [markdown]
# ### Nokia dataset

# %%
nk_data, nk_labels = create_dataset(pos_nokia, neg_nokia)

# %%
nk_data_np = np.vstack((nk_data, nk_labels)).T
np.random.shuffle(nk_data_np)
nk_features = list(nk_data_np[:, 0])
nk_labels = list(nk_data_np[:, 1])

# %% [markdown]
# #### Baseline

# %%
PRINT_ERRORS = 0
classify_rule_based(nk_features, nk_labels, sent_dict, trigram_ps=1, trigram_ns=1)
# Out:
# Sigma: 1
# Threshold: 0
# Mean score: -25.14963503649635
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
# (0.2245566592175012, -25.14963503649635)

# %% [markdown]
# #### Tuned

# %%
optimize_rule_based(nk_data, nk_labels, sent_dict, sigma_range=[-4, 4], trigram_ps=-7, trigram_ns=1)
# Out:
# Train with default threshold..
# Sigma: 1
# Threshold: 0
# Mean score: -25.14963503649635
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
# Train with optimized threshold, default sigma..
# Sigma: 1
# Threshold: -25.14963503649635
# Mean score: -25.14963503649635
# Accuracy (All)=0.54 (148/274)
#
# Positive scores..
# Precision (Pos)=0.71 (115/162)
# Recall (Pos)=0.59 (115/194)
# F-measure (Pos)=0.64
# Negative scores..
# Precision (Neg)=0.29 (33/112)
# Recall (Neg)=0.41 (33/80)
# F-measure (Neg)=0.34
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.49
#
#
# Optimizing sigma..
#
# Sigma: -4.0
#
# Sigma: -4.0
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.919191919191919
#
# Sigma: -3.919191919191919
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.8383838383838382
#
# Sigma: -3.8383838383838382
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.757575757575758
#
# Sigma: -3.757575757575758
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.676767676767677
#
# Sigma: -3.676767676767677
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.595959595959596
#
# Sigma: -3.595959595959596
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.515151515151515
#
# Sigma: -3.515151515151515
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.4343434343434343
#
# Sigma: -3.4343434343434343
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.3535353535353534
#
# Sigma: -3.3535353535353534
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.2727272727272725
#
# Sigma: -3.2727272727272725
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.191919191919192
#
# Sigma: -3.191919191919192
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.111111111111111
#
# Sigma: -3.111111111111111
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -3.0303030303030303
#
# Sigma: -3.0303030303030303
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.9494949494949494
#
# Sigma: -2.9494949494949494
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.8686868686868685
#
# Sigma: -2.8686868686868685
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.787878787878788
#
# Sigma: -2.787878787878788
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.7070707070707067
#
# Sigma: -2.7070707070707067
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.6262626262626263
#
# Sigma: -2.6262626262626263
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.5454545454545454
#
# Sigma: -2.5454545454545454
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.4646464646464645
#
# Sigma: -2.4646464646464645
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.3838383838383836
#
# Sigma: -2.3838383838383836
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.3030303030303028
#
# Sigma: -2.3030303030303028
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.2222222222222223
#
# Sigma: -2.2222222222222223
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.141414141414141
#
# Sigma: -2.141414141414141
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -2.0606060606060606
#
# Sigma: -2.0606060606060606
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.9797979797979797
#
# Sigma: -1.9797979797979797
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.8989898989898988
#
# Sigma: -1.8989898989898988
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.818181818181818
#
# Sigma: -1.818181818181818
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.737373737373737
#
# Sigma: -1.737373737373737
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.6565656565656566
#
# Sigma: -1.6565656565656566
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.5757575757575757
#
# Sigma: -1.5757575757575757
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.4949494949494948
#
# Sigma: -1.4949494949494948
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.414141414141414
#
# Sigma: -1.414141414141414
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.333333333333333
#
# Sigma: -1.333333333333333
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.2525252525252522
#
# Sigma: -1.2525252525252522
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.1717171717171713
#
# Sigma: -1.1717171717171713
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.0909090909090908
#
# Sigma: -1.0909090909090908
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -1.01010101010101
#
# Sigma: -1.01010101010101
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.9292929292929291
#
# Sigma: -0.9292929292929291
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.8484848484848482
#
# Sigma: -0.8484848484848482
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.7676767676767673
#
# Sigma: -0.7676767676767673
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.6868686868686864
#
# Sigma: -0.6868686868686864
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.606060606060606
#
# Sigma: -0.606060606060606
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.5252525252525251
#
# Sigma: -0.5252525252525251
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.4444444444444442
#
# Sigma: -0.4444444444444442
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.3636363636363633
#
# Sigma: -0.3636363636363633
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.28282828282828243
#
# Sigma: -0.28282828282828243
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.20202020202020154
#
# Sigma: -0.20202020202020154
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.1212121212121211
#
# Sigma: -0.1212121212121211
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: -0.04040404040404022
#
# Sigma: -0.04040404040404022
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.29 (80/274)
#
# Positive scores..
# Precision (Pos)=0.00 (0/0)
# Recall (Pos)=0.00 (0/194)
# F-measure (Pos)=0.00
# Negative scores..
# Precision (Neg)=0.29 (80/274)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.15
# Recall (Mean)=0.50
# F-measure (Mean)=0.22
#
#
# Sigma: 0.040404040404040664
#
# Sigma: 0.040404040404040664
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.30 (83/274)
#
# Positive scores..
# Precision (Pos)=1.00 (3/3)
# Recall (Pos)=0.02 (3/194)
# F-measure (Pos)=0.03
# Negative scores..
# Precision (Neg)=0.30 (80/271)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.51
# F-measure (Mean)=0.24
#
#
# Sigma: 0.12121212121212199
#
# Sigma: 0.12121212121212199
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.31 (85/274)
#
# Positive scores..
# Precision (Pos)=1.00 (5/5)
# Recall (Pos)=0.03 (5/194)
# F-measure (Pos)=0.05
# Negative scores..
# Precision (Neg)=0.30 (80/269)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.51
# F-measure (Mean)=0.25
#
#
# Sigma: 0.20202020202020243
#
# Sigma: 0.20202020202020243
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.31 (86/274)
#
# Positive scores..
# Precision (Pos)=1.00 (6/6)
# Recall (Pos)=0.03 (6/194)
# F-measure (Pos)=0.06
# Negative scores..
# Precision (Neg)=0.30 (80/268)
# Recall (Neg)=1.00 (80/80)
# F-measure (Neg)=0.46
#
# Mean scores..
# Precision (Mean)=0.65
# Recall (Mean)=0.52
# F-measure (Mean)=0.26
#
#
# Sigma: 0.2828282828282829
#
# Sigma: 0.2828282828282829
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.31 (85/274)
#
# Positive scores..
# Precision (Pos)=0.86 (6/7)
# Recall (Pos)=0.03 (6/194)
# F-measure (Pos)=0.06
# Negative scores..
# Precision (Neg)=0.30 (79/267)
# Recall (Neg)=0.99 (79/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.51
# F-measure (Mean)=0.26
#
#
# Sigma: 0.3636363636363642
#
# Sigma: 0.3636363636363642
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.32 (88/274)
#
# Positive scores..
# Precision (Pos)=0.79 (11/14)
# Recall (Pos)=0.06 (11/194)
# F-measure (Pos)=0.10
# Negative scores..
# Precision (Neg)=0.30 (77/260)
# Recall (Neg)=0.96 (77/80)
# F-measure (Neg)=0.45
#
# Mean scores..
# Precision (Mean)=0.54
# Recall (Mean)=0.51
# F-measure (Mean)=0.28
#
#
# Sigma: 0.44444444444444464
#
# Sigma: 0.44444444444444464
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.32 (89/274)
#
# Positive scores..
# Precision (Pos)=0.71 (15/21)
# Recall (Pos)=0.08 (15/194)
# F-measure (Pos)=0.14
# Negative scores..
# Precision (Neg)=0.29 (74/253)
# Recall (Neg)=0.92 (74/80)
# F-measure (Neg)=0.44
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.29
#
#
# Sigma: 0.525252525252526
#
# Sigma: 0.525252525252526
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.33 (90/274)
#
# Positive scores..
# Precision (Pos)=0.71 (17/24)
# Recall (Pos)=0.09 (17/194)
# F-measure (Pos)=0.15
# Negative scores..
# Precision (Neg)=0.29 (73/250)
# Recall (Neg)=0.91 (73/80)
# F-measure (Neg)=0.44
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.30
#
#
# Sigma: 0.6060606060606064
#
# Sigma: 0.6060606060606064
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.33 (91/274)
#
# Positive scores..
# Precision (Pos)=0.70 (19/27)
# Recall (Pos)=0.10 (19/194)
# F-measure (Pos)=0.17
# Negative scores..
# Precision (Neg)=0.29 (72/247)
# Recall (Neg)=0.90 (72/80)
# F-measure (Neg)=0.44
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.30
#
#
# Sigma: 0.6868686868686869
#
# Sigma: 0.6868686868686869
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.34 (94/274)
#
# Positive scores..
# Precision (Pos)=0.72 (23/32)
# Recall (Pos)=0.12 (23/194)
# F-measure (Pos)=0.20
# Negative scores..
# Precision (Neg)=0.29 (71/242)
# Recall (Neg)=0.89 (71/80)
# F-measure (Neg)=0.44
#
# Mean scores..
# Precision (Mean)=0.51
# Recall (Mean)=0.50
# F-measure (Mean)=0.32
#
#
# Sigma: 0.7676767676767682
#
# Sigma: 0.7676767676767682
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.35 (97/274)
#
# Positive scores..
# Precision (Pos)=0.71 (29/41)
# Recall (Pos)=0.15 (29/194)
# F-measure (Pos)=0.24
# Negative scores..
# Precision (Neg)=0.29 (68/233)
# Recall (Neg)=0.85 (68/80)
# F-measure (Neg)=0.43
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.34
#
#
# Sigma: 0.8484848484848486
#
# Sigma: 0.8484848484848486
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.38 (103/274)
#
# Positive scores..
# Precision (Pos)=0.73 (37/51)
# Recall (Pos)=0.19 (37/194)
# F-measure (Pos)=0.30
# Negative scores..
# Precision (Neg)=0.30 (66/223)
# Recall (Neg)=0.82 (66/80)
# F-measure (Neg)=0.43
#
# Mean scores..
# Precision (Mean)=0.51
# Recall (Mean)=0.51
# F-measure (Mean)=0.36
#
#
# Sigma: 0.92929292929293
#
# Sigma: 0.92929292929293
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.38 (105/274)
#
# Positive scores..
# Precision (Pos)=0.71 (42/59)
# Recall (Pos)=0.22 (42/194)
# F-measure (Pos)=0.33
# Negative scores..
# Precision (Neg)=0.29 (63/215)
# Recall (Neg)=0.79 (63/80)
# F-measure (Neg)=0.42
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.38
#
#
# Sigma: 1.0101010101010104
#
# Sigma: 1.0101010101010104
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.39 (107/274)
#
# Positive scores..
# Precision (Pos)=0.70 (48/69)
# Recall (Pos)=0.25 (48/194)
# F-measure (Pos)=0.36
# Negative scores..
# Precision (Neg)=0.29 (59/205)
# Recall (Neg)=0.74 (59/80)
# F-measure (Neg)=0.41
#
# Mean scores..
# Precision (Mean)=0.49
# Recall (Mean)=0.49
# F-measure (Mean)=0.39
#
#
# Sigma: 1.0909090909090917
#
# Sigma: 1.0909090909090917
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.41 (111/274)
#
# Positive scores..
# Precision (Pos)=0.69 (56/81)
# Recall (Pos)=0.29 (56/194)
# F-measure (Pos)=0.40
# Negative scores..
# Precision (Neg)=0.28 (55/193)
# Recall (Neg)=0.69 (55/80)
# F-measure (Neg)=0.40
#
# Mean scores..
# Precision (Mean)=0.49
# Recall (Mean)=0.49
# F-measure (Mean)=0.40
#
#
# Sigma: 1.1717171717171722
#
# Sigma: 1.1717171717171722
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.41 (112/274)
#
# Positive scores..
# Precision (Pos)=0.68 (60/88)
# Recall (Pos)=0.31 (60/194)
# F-measure (Pos)=0.42
# Negative scores..
# Precision (Neg)=0.28 (52/186)
# Recall (Neg)=0.65 (52/80)
# F-measure (Neg)=0.39
#
# Mean scores..
# Precision (Mean)=0.48
# Recall (Mean)=0.48
# F-measure (Mean)=0.40
#
#
# Sigma: 1.2525252525252526
#
# Sigma: 1.2525252525252526
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.42 (116/274)
#
# Positive scores..
# Precision (Pos)=0.69 (66/96)
# Recall (Pos)=0.34 (66/194)
# F-measure (Pos)=0.45
# Negative scores..
# Precision (Neg)=0.28 (50/178)
# Recall (Neg)=0.62 (50/80)
# F-measure (Neg)=0.38
#
# Mean scores..
# Precision (Mean)=0.48
# Recall (Mean)=0.48
# F-measure (Mean)=0.42
#
#
# Sigma: 1.333333333333334
#
# Sigma: 1.333333333333334
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.46 (125/274)
#
# Positive scores..
# Precision (Pos)=0.71 (76/107)
# Recall (Pos)=0.39 (76/194)
# F-measure (Pos)=0.50
# Negative scores..
# Precision (Neg)=0.29 (49/167)
# Recall (Neg)=0.61 (49/80)
# F-measure (Neg)=0.39
#
# Mean scores..
# Precision (Mean)=0.50
# Recall (Mean)=0.50
# F-measure (Mean)=0.45
#
#
# Sigma: 1.4141414141414144
#
# Sigma: 1.4141414141414144
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.48 (132/274)
#
# Positive scores..
# Precision (Pos)=0.72 (85/118)
# Recall (Pos)=0.44 (85/194)
# F-measure (Pos)=0.54
# Negative scores..
# Precision (Neg)=0.30 (47/156)
# Recall (Neg)=0.59 (47/80)
# F-measure (Neg)=0.39
#
# Mean scores..
# Precision (Mean)=0.51
# Recall (Mean)=0.51
# F-measure (Mean)=0.47
#
#
# Sigma: 1.4949494949494957
#
# Sigma: 1.4949494949494957
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.51 (139/274)
#
# Positive scores..
# Precision (Pos)=0.73 (93/127)
# Recall (Pos)=0.48 (93/194)
# F-measure (Pos)=0.58
# Negative scores..
# Precision (Neg)=0.31 (46/147)
# Recall (Neg)=0.57 (46/80)
# F-measure (Neg)=0.40
#
# Mean scores..
# Precision (Mean)=0.52
# Recall (Mean)=0.53
# F-measure (Mean)=0.49
#
#
# Sigma: 1.5757575757575761
#
# Sigma: 1.5757575757575761
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.52 (142/274)
#
# Positive scores..
# Precision (Pos)=0.73 (99/136)
# Recall (Pos)=0.51 (99/194)
# F-measure (Pos)=0.59
# Negative scores..
# Precision (Neg)=0.31 (43/138)
# Recall (Neg)=0.54 (43/80)
# F-measure (Neg)=0.39
#
# Mean scores..
# Precision (Mean)=0.52
# Recall (Mean)=0.52
# F-measure (Mean)=0.49
#
# Found better sigma: 1.5757575757575761
#
# Sigma: 1.6565656565656575
#
# Sigma: 1.6565656565656575
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.54 (147/274)
#
# Positive scores..
# Precision (Pos)=0.73 (106/145)
# Recall (Pos)=0.55 (106/194)
# F-measure (Pos)=0.62
# Negative scores..
# Precision (Neg)=0.32 (41/129)
# Recall (Neg)=0.51 (41/80)
# F-measure (Neg)=0.39
#
# Mean scores..
# Precision (Mean)=0.52
# Recall (Mean)=0.53
# F-measure (Mean)=0.50
#
# Found better sigma: 1.6565656565656575
#
# Sigma: 1.737373737373738
#
# Sigma: 1.737373737373738
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.55 (152/274)
#
# Positive scores..
# Precision (Pos)=0.74 (112/152)
# Recall (Pos)=0.58 (112/194)
# F-measure (Pos)=0.64
# Negative scores..
# Precision (Neg)=0.33 (40/122)
# Recall (Neg)=0.50 (40/80)
# F-measure (Neg)=0.39
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.54
# F-measure (Mean)=0.52
#
# Found better sigma: 1.737373737373738
#
# Sigma: 1.8181818181818183
#
# Sigma: 1.8181818181818183
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.56 (154/274)
#
# Positive scores..
# Precision (Pos)=0.73 (116/158)
# Recall (Pos)=0.60 (116/194)
# F-measure (Pos)=0.66
# Negative scores..
# Precision (Neg)=0.33 (38/116)
# Recall (Neg)=0.47 (38/80)
# F-measure (Neg)=0.38
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.54
# F-measure (Mean)=0.52
#
# Found better sigma: 1.8181818181818183
#
# Sigma: 1.8989898989898997
#
# Sigma: 1.8989898989898997
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.58 (159/274)
#
# Positive scores..
# Precision (Pos)=0.73 (125/171)
# Recall (Pos)=0.64 (125/194)
# F-measure (Pos)=0.68
# Negative scores..
# Precision (Neg)=0.33 (34/103)
# Recall (Neg)=0.42 (34/80)
# F-measure (Neg)=0.36
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.52
#
# Found better sigma: 1.8989898989898997
#
# Sigma: 1.9797979797979801
#
# Sigma: 1.9797979797979801
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.59 (163/274)
#
# Positive scores..
# Precision (Pos)=0.73 (130/177)
# Recall (Pos)=0.67 (130/194)
# F-measure (Pos)=0.70
# Negative scores..
# Precision (Neg)=0.34 (33/97)
# Recall (Neg)=0.41 (33/80)
# F-measure (Neg)=0.37
#
# Mean scores..
# Precision (Mean)=0.54
# Recall (Mean)=0.54
# F-measure (Mean)=0.53
#
# Found better sigma: 1.9797979797979801
#
# Sigma: 2.0606060606060614
#
# Sigma: 2.0606060606060614
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.61 (166/274)
#
# Positive scores..
# Precision (Pos)=0.73 (136/186)
# Recall (Pos)=0.70 (136/194)
# F-measure (Pos)=0.71
# Negative scores..
# Precision (Neg)=0.34 (30/88)
# Recall (Neg)=0.37 (30/80)
# F-measure (Neg)=0.35
#
# Mean scores..
# Precision (Mean)=0.54
# Recall (Mean)=0.54
# F-measure (Mean)=0.53
#
#
# Sigma: 2.141414141414142
#
# Sigma: 2.141414141414142
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.62 (169/274)
#
# Positive scores..
# Precision (Pos)=0.73 (142/195)
# Recall (Pos)=0.73 (142/194)
# F-measure (Pos)=0.73
# Negative scores..
# Precision (Neg)=0.34 (27/79)
# Recall (Neg)=0.34 (27/80)
# F-measure (Neg)=0.33
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.53
#
#
# Sigma: 2.2222222222222223
#
# Sigma: 2.2222222222222223
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.62 (170/274)
#
# Positive scores..
# Precision (Pos)=0.73 (144/198)
# Recall (Pos)=0.74 (144/194)
# F-measure (Pos)=0.73
# Negative scores..
# Precision (Neg)=0.34 (26/76)
# Recall (Neg)=0.32 (26/80)
# F-measure (Neg)=0.33
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.53
#
#
# Sigma: 2.3030303030303036
#
# Sigma: 2.3030303030303036
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.63 (172/274)
#
# Positive scores..
# Precision (Pos)=0.72 (149/206)
# Recall (Pos)=0.77 (149/194)
# F-measure (Pos)=0.74
# Negative scores..
# Precision (Neg)=0.34 (23/68)
# Recall (Neg)=0.29 (23/80)
# F-measure (Neg)=0.30
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.52
#
#
# Sigma: 2.383838383838384
#
# Sigma: 2.383838383838384
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.63 (173/274)
#
# Positive scores..
# Precision (Pos)=0.72 (151/209)
# Recall (Pos)=0.78 (151/194)
# F-measure (Pos)=0.74
# Negative scores..
# Precision (Neg)=0.34 (22/65)
# Recall (Neg)=0.27 (22/80)
# F-measure (Neg)=0.30
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.52
#
#
# Sigma: 2.4646464646464654
#
# Sigma: 2.4646464646464654
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.64 (176/274)
#
# Positive scores..
# Precision (Pos)=0.73 (154/212)
# Recall (Pos)=0.79 (154/194)
# F-measure (Pos)=0.75
# Negative scores..
# Precision (Neg)=0.35 (22/62)
# Recall (Neg)=0.27 (22/80)
# F-measure (Neg)=0.30
#
# Mean scores..
# Precision (Mean)=0.54
# Recall (Mean)=0.53
# F-measure (Mean)=0.53
#
#
# Sigma: 2.545454545454546
#
# Sigma: 2.545454545454546
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.65 (178/274)
#
# Positive scores..
# Precision (Pos)=0.72 (161/224)
# Recall (Pos)=0.83 (161/194)
# F-measure (Pos)=0.76
# Negative scores..
# Precision (Neg)=0.34 (17/50)
# Recall (Neg)=0.21 (17/80)
# F-measure (Neg)=0.26
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.52
# F-measure (Mean)=0.51
#
#
# Sigma: 2.626262626262627
#
# Sigma: 2.626262626262627
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.66 (180/274)
#
# Positive scores..
# Precision (Pos)=0.72 (164/228)
# Recall (Pos)=0.85 (164/194)
# F-measure (Pos)=0.77
# Negative scores..
# Precision (Neg)=0.35 (16/46)
# Recall (Neg)=0.20 (16/80)
# F-measure (Neg)=0.25
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.52
# F-measure (Mean)=0.51
#
#
# Sigma: 2.7070707070707076
#
# Sigma: 2.7070707070707076
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.68 (186/274)
#
# Positive scores..
# Precision (Pos)=0.73 (170/234)
# Recall (Pos)=0.88 (170/194)
# F-measure (Pos)=0.79
# Negative scores..
# Precision (Neg)=0.40 (16/40)
# Recall (Neg)=0.20 (16/80)
# F-measure (Neg)=0.26
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.54
# F-measure (Mean)=0.53
#
#
# Sigma: 2.787878787878788
#
# Sigma: 2.787878787878788
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.68 (186/274)
#
# Positive scores..
# Precision (Pos)=0.72 (172/238)
# Recall (Pos)=0.89 (172/194)
# F-measure (Pos)=0.79
# Negative scores..
# Precision (Neg)=0.39 (14/36)
# Recall (Neg)=0.17 (14/80)
# F-measure (Neg)=0.24
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.53
# F-measure (Mean)=0.51
#
#
# Sigma: 2.8686868686868694
#
# Sigma: 2.8686868686868694
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (189/274)
#
# Positive scores..
# Precision (Pos)=0.72 (176/243)
# Recall (Pos)=0.91 (176/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.42 (13/31)
# Recall (Neg)=0.16 (13/80)
# F-measure (Neg)=0.23
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.53
# F-measure (Mean)=0.52
#
#
# Sigma: 2.94949494949495
#
# Sigma: 2.94949494949495
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (189/274)
#
# Positive scores..
# Precision (Pos)=0.72 (176/243)
# Recall (Pos)=0.91 (176/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.42 (13/31)
# Recall (Neg)=0.16 (13/80)
# F-measure (Neg)=0.23
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.53
# F-measure (Mean)=0.52
#
#
# Sigma: 3.030303030303031
#
# Sigma: 3.030303030303031
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (189/274)
#
# Positive scores..
# Precision (Pos)=0.72 (179/249)
# Recall (Pos)=0.92 (179/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.40 (10/25)
# Recall (Neg)=0.12 (10/80)
# F-measure (Neg)=0.19
#
# Mean scores..
# Precision (Mean)=0.56
# Recall (Mean)=0.52
# F-measure (Mean)=0.50
#
#
# Sigma: 3.1111111111111116
#
# Sigma: 3.1111111111111116
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (188/274)
#
# Positive scores..
# Precision (Pos)=0.71 (180/252)
# Recall (Pos)=0.93 (180/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.36 (8/22)
# Recall (Neg)=0.10 (8/80)
# F-measure (Neg)=0.15
#
# Mean scores..
# Precision (Mean)=0.54
# Recall (Mean)=0.51
# F-measure (Mean)=0.48
#
#
# Sigma: 3.191919191919193
#
# Sigma: 3.191919191919193
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (189/274)
#
# Positive scores..
# Precision (Pos)=0.72 (181/253)
# Recall (Pos)=0.93 (181/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.38 (8/21)
# Recall (Neg)=0.10 (8/80)
# F-measure (Neg)=0.16
#
# Mean scores..
# Precision (Mean)=0.55
# Recall (Mean)=0.52
# F-measure (Mean)=0.48
#
#
# Sigma: 3.2727272727272734
#
# Sigma: 3.2727272727272734
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (189/274)
#
# Positive scores..
# Precision (Pos)=0.72 (181/253)
# Recall (Pos)=0.93 (181/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.38 (8/21)
# Recall (Neg)=0.10 (8/80)
# F-measure (Neg)=0.16
#
# Mean scores..
# Precision (Mean)=0.55
# Recall (Mean)=0.52
# F-measure (Mean)=0.48
#
#
# Sigma: 3.353535353535354
#
# Sigma: 3.353535353535354
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (188/274)
#
# Positive scores..
# Precision (Pos)=0.71 (181/254)
# Recall (Pos)=0.93 (181/194)
# F-measure (Pos)=0.80
# Negative scores..
# Precision (Neg)=0.35 (7/20)
# Recall (Neg)=0.09 (7/80)
# F-measure (Neg)=0.14
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.51
# F-measure (Mean)=0.47
#
#
# Sigma: 3.434343434343435
#
# Sigma: 3.434343434343435
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (189/274)
#
# Positive scores..
# Precision (Pos)=0.71 (182/255)
# Recall (Pos)=0.94 (182/194)
# F-measure (Pos)=0.81
# Negative scores..
# Precision (Neg)=0.37 (7/19)
# Recall (Neg)=0.09 (7/80)
# F-measure (Neg)=0.14
#
# Mean scores..
# Precision (Mean)=0.54
# Recall (Mean)=0.51
# F-measure (Mean)=0.47
#
#
# Sigma: 3.5151515151515156
#
# Sigma: 3.5151515151515156
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.69 (190/274)
#
# Positive scores..
# Precision (Pos)=0.71 (183/256)
# Recall (Pos)=0.94 (183/194)
# F-measure (Pos)=0.81
# Negative scores..
# Precision (Neg)=0.39 (7/18)
# Recall (Neg)=0.09 (7/80)
# F-measure (Neg)=0.14
#
# Mean scores..
# Precision (Mean)=0.55
# Recall (Mean)=0.52
# F-measure (Mean)=0.47
#
#
# Sigma: 3.595959595959597
#
# Sigma: 3.595959595959597
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.70 (192/274)
#
# Positive scores..
# Precision (Pos)=0.71 (187/262)
# Recall (Pos)=0.96 (187/194)
# F-measure (Pos)=0.81
# Negative scores..
# Precision (Neg)=0.42 (5/12)
# Recall (Neg)=0.06 (5/80)
# F-measure (Neg)=0.11
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.51
# F-measure (Mean)=0.46
#
#
# Sigma: 3.6767676767676774
#
# Sigma: 3.6767676767676774
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.70 (192/274)
#
# Positive scores..
# Precision (Pos)=0.71 (187/262)
# Recall (Pos)=0.96 (187/194)
# F-measure (Pos)=0.81
# Negative scores..
# Precision (Neg)=0.42 (5/12)
# Recall (Neg)=0.06 (5/80)
# F-measure (Neg)=0.11
#
# Mean scores..
# Precision (Mean)=0.57
# Recall (Mean)=0.51
# F-measure (Mean)=0.46
#
#
# Sigma: 3.757575757575758
#
# Sigma: 3.757575757575758
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.70 (193/274)
#
# Positive scores..
# Precision (Pos)=0.71 (188/263)
# Recall (Pos)=0.97 (188/194)
# F-measure (Pos)=0.82
# Negative scores..
# Precision (Neg)=0.45 (5/11)
# Recall (Neg)=0.06 (5/80)
# F-measure (Neg)=0.11
#
# Mean scores..
# Precision (Mean)=0.58
# Recall (Mean)=0.52
# F-measure (Mean)=0.46
#
#
# Sigma: 3.838383838383839
#
# Sigma: 3.838383838383839
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.71 (194/274)
#
# Positive scores..
# Precision (Pos)=0.71 (190/266)
# Recall (Pos)=0.98 (190/194)
# F-measure (Pos)=0.82
# Negative scores..
# Precision (Neg)=0.50 (4/8)
# Recall (Neg)=0.05 (4/80)
# F-measure (Neg)=0.09
#
# Mean scores..
# Precision (Mean)=0.61
# Recall (Mean)=0.51
# F-measure (Mean)=0.46
#
#
# Sigma: 3.9191919191919196
#
# Sigma: 3.9191919191919196
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.72 (196/274)
#
# Positive scores..
# Precision (Pos)=0.72 (192/268)
# Recall (Pos)=0.99 (192/194)
# F-measure (Pos)=0.82
# Negative scores..
# Precision (Neg)=0.67 (4/6)
# Recall (Neg)=0.05 (4/80)
# F-measure (Neg)=0.09
#
# Mean scores..
# Precision (Mean)=0.69
# Recall (Mean)=0.52
# F-measure (Mean)=0.46
#
#
# Sigma: 4.0
#
# Sigma: 4.0
# Threshold: -25.14963503649635
# Mean score: -43.222627737226276
# Accuracy (All)=0.72 (196/274)
#
# Positive scores..
# Precision (Pos)=0.72 (192/268)
# Recall (Pos)=0.99 (192/194)
# F-measure (Pos)=0.82
# Negative scores..
# Precision (Neg)=0.67 (4/6)
# Recall (Neg)=0.05 (4/80)
# F-measure (Neg)=0.09
#
# Mean scores..
# Precision (Mean)=0.69
# Recall (Mean)=0.52
# F-measure (Mean)=0.46
#
#
# Final results
# Best mean f-measure: 0.5336255443073613
# Best sigma: 1.9797979797979801
# Best threshold: -25.14963503649635

# %%
classify_rule_based(nk_data, nk_labels, sent_dict, threshold=-25.15, sigma=2.22, trigram_ps=-7, trigram_ns=1)
# Out:
# Sigma: 2.22
# Threshold: -25.15
# Mean score: -43.222627737226276
# Accuracy (All)=0.62 (170/274)
#
# Positive scores..
# Precision (Pos)=0.73 (144/198)
# Recall (Pos)=0.74 (144/194)
# F-measure (Pos)=0.73
# Negative scores..
# Precision (Neg)=0.34 (26/76)
# Recall (Neg)=0.32 (26/80)
# F-measure (Neg)=0.33
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.53
# (0.5281779074876155, -43.222627737226276)

# %%
PRINT_ERRORS=1
classify_rule_based(nk_data, nk_labels, sent_dict, threshold=-25.15, sigma=2.22, trigram_ps=-7, trigram_ns=1)
PRINT_ERRORS=0
# Out:
# ERROR (pos classed as neg %0.2f): there is much which has been said in other reviews about the features of this phone , it is a great phone , mine worked without any problems right out of the box .
# ERROR (pos classed as neg %0.2f): here 's the brief synopsis : the phone is tiny , cute , feels kind of " plastic-like " ( as if it might break ) , but seems pretty sturdy .
# ERROR (pos classed as neg %0.2f): it has lots of little cute features , my favorite being the games and the pim ( personal information manager -- i.e. organizer ) , and the radio !
# ERROR (pos classed as neg %0.2f): the phone comes with okay ringtones , some decent backgrounds / screensavers , but the phone has very little memory ( mine had 230kb as it arrived from amazon , so you do n't have too many options on what you can put on there ) .
# ERROR (pos classed as neg %0.2f): in all fairness , customer reps are very nice , and they ( most of them ) try hard to answer your questions .
# ERROR (pos classed as neg %0.2f): i 'm staying with sprint , and though i fear that their csr is n't nearly as good as t-mobile 's , the clarity of their reception is exceptional .
# ERROR (pos classed as neg %0.2f): while i like the performance of the phone in every regard , i would buy another one solely upon the apparent indestructibility of it .
# ERROR (pos classed as neg %0.2f): from the speakerphone that can be used up to 15 feet away with clarity , to the downloadable poly-graphic megatones that adds a personal touch to this nifty phone .
# ERROR (neg classed as pos %0.2f): i treat the battery well and it has lasted .
# ERROR (pos classed as neg %0.2f): great battery life , perfect size , but a tid bit quieter than i would like .
# ERROR (pos classed as neg %0.2f): while i had the phone , the positive features were : good sound quality and an excellent fm phone and earpiece .
# ERROR (pos classed as neg %0.2f): the two biggest things is the excellent working speakerphone " unlike the nokia 3650 " and the superb reception nokia is known for in the gsm phones they make ...
# ERROR (neg classed as pos %0.2f): anything this phone does , it does perfectly .
# ERROR (pos classed as neg %0.2f): you can be up to about 3 feet away from it and it will still work perfectly .
# ERROR (neg classed as pos %0.2f): i bought this phone for my trip to south africa and it worked almost perfectly .
# ERROR (neg classed as pos %0.2f): anywhere i went in south africa this phone received full bar reception .
# ERROR (neg classed as pos %0.2f): another benefit of this phone is that it is truly an international phone ; the 6610 is sold in almost everywhere in the world .
# ERROR (pos classed as neg %0.2f): this means that there is a good chance that this phone will not break easily like typical american phones .
# ERROR (neg classed as pos %0.2f): when you put this phone in your pocket you forget it is there ; it is unbelievably small and oh , so light .
# ERROR (pos classed as neg %0.2f): this is a benefit for many reasons ; one being just for appearance , your pants wo n't be bulging with this phone in your pocket .
# ERROR (neg classed as pos %0.2f): i 've used the speakerphone for almost two hours once and the battery did not even go down one single bar .
# ERROR (neg classed as pos %0.2f): overall , i highly recommend this phone .
# ERROR (pos classed as neg %0.2f): surfing the web on it is nice as well , i just wish there were more wap pages available .
# ERROR (pos classed as neg %0.2f): although the nokia 6610 is a little short on the features department , it is an outstanding piece of hardware for doing what it was primarily meant to do : to be a wireless telephone .
# ERROR (neg classed as pos %0.2f): i like the size and weight of this little critter .
# ERROR (neg classed as pos %0.2f): i am able to carry it close to my body , in places where other phones are not so easily concealed .
# ERROR (pos classed as neg %0.2f): the screen is bright , easy to see in the daylight , with nice colors .
# ERROR (neg classed as pos %0.2f): it receives very nice mms pictures from other gsm phones .
# ERROR (neg classed as pos %0.2f): - light , compact design
# ERROR (neg classed as pos %0.2f): - solid , high-quality construction
# ERROR (neg classed as pos %0.2f): - bright , visible screen
# ERROR (neg classed as pos %0.2f): i like the speakphone function a lot .
# ERROR (neg classed as pos %0.2f): i like the automatic key lock function .
# ERROR (neg classed as pos %0.2f): the phone is very light weight .
# ERROR (neg classed as pos %0.2f): while going for a cellphone , i was fully determined to buy a nokia only as it is the best in cellphones .
# ERROR (neg classed as pos %0.2f): it has all the features one would need in a cellphone .
# ERROR (pos classed as neg %0.2f): this phone is very user-friendly , easy to manipulate &#38; very convenient to scroll in menu etc .
# ERROR (neg classed as pos %0.2f): its speakerphone option allows us to do long talks conveniently , lying on bed &#38; phone lying by your pillowside .
# ERROR (neg classed as pos %0.2f): i am enjoying my phone a lot ....
# ERROR (neg classed as pos %0.2f): it has lots of features such as the calendar which works like my outlook calendar .
# ERROR (pos classed as neg %0.2f): navigating through the menus is super easy , especially if you have owned a previous model nokia phone .
# ERROR (pos classed as neg %0.2f): battery life is very good , i use it every day and i have to charge it every 5 or 6 days or so .
# ERROR (pos classed as neg %0.2f): the loud speaker function on the 6610 is great because you do n't need to put your phone right next to your ear to talk .
# ERROR (neg classed as pos %0.2f): this is the best phone i have seen .
# ERROR (pos classed as neg %0.2f): we hardly ever have to charge them , get great reception ( live in chicago ) , and the customization and applications are awesome .
# ERROR (neg classed as pos %0.2f): i bought this slick phone and i am very happy with it .
# ERROR (pos classed as neg %0.2f): the first night i got this phone i put it next to me when i went to bed just to listen to my favorite music station and the handset itself doesnt weight anything its too light and feel so comfy with it .
# ERROR (pos classed as neg %0.2f): technology wise , i think this is awesome plus the speaker makes it even great ! ! ! ! i love this phone ! ! !
# ERROR (neg classed as pos %0.2f): for a specific location , i still think its a great phone .
# ERROR (pos classed as neg %0.2f): this really is a great little phone ; its got nice features , a beatiful screen , great ergonomics , and its tiny !
# ERROR (pos classed as neg %0.2f): this phone won me over , and a big seller was the size ; it fits nicely into any pocket without falling out .
# ERROR (neg classed as pos %0.2f): the battery life is amazing .
# ERROR (pos classed as neg %0.2f): the hands-free speakerphone is quite powerful ( like the motorola phone , i used to own ) .
# ERROR (pos classed as neg %0.2f): additionally , it has more fun stuff like more tones , wallpapers , screensaver , stop clock , alarm , java applications ( chess , currency converter etc. )
# ERROR (pos classed as neg %0.2f): the mms technology is very well integrated with this phone , which you will enjoy .
# ERROR (pos classed as neg %0.2f): not only is it the perfect size ( not too small , not too large ) , it also has all the features a high-tech phone user would want .
# ERROR (neg classed as pos %0.2f): even better , with the optional headset you can listen to music over the integrated radio .
# ERROR (pos classed as neg %0.2f): it has great battery life , fm radio , excellent signal , hands free speakerphone ( which i have to say is probably my favorite function ) and downloadable java apps .
# ERROR (neg classed as pos %0.2f): great features .. .
# ERROR (pos classed as neg %0.2f): i did a ton of research and settled on this phone because of the small size , speakerphone option , great priced calling plan and access to my corporate email .
# ERROR (pos classed as neg %0.2f): service is great as far as i can tell , features work like a charm , ringtones are high quality if you buy them from t-mobile and aim is great .
# ERROR (neg classed as pos %0.2f): the speakerphone works better than any speakerphone i 've ever had .
# ERROR (pos classed as neg %0.2f): i have not had any distortion problems with this phone and am more pleased with this phone than any i 've used before .
# ERROR (neg classed as pos %0.2f): the battery is alot better than most of the phones out there .
# ERROR (neg classed as pos %0.2f): great screen and great sound .
# ERROR (pos classed as neg %0.2f): it is just a tad small to hold to your ear with your shoulder , but that is solved with the very comfortable handsfree ear-piece which is included .
# ERROR (neg classed as pos %0.2f): the ringtones included are awesome , and did i mention they were polyphonic ?
# ERROR (pos classed as neg %0.2f): the phone also sports an image gallery ( with option camera attachment ) , a calendar / organizer , alarm clock with snooze , fm radio ( way cool , even if it is just through an ear-peice ) , games , java applications and gprs high-speed internet connection .
# ERROR (pos classed as neg %0.2f): the gprs connection is sometimes slow , and writing instant messages with the included aol instant messenger software is a pain , but the other t-zones applications are quite useful .
# ERROR (neg classed as pos %0.2f): nokia makes a great phone , that 's clear .
# ERROR (pos classed as neg %0.2f): with all its complicated features , the menus are easily accessible and the quality of the features is great .
# ERROR (neg classed as pos %0.2f): this phone is good with a huge array of features built into it .
# ERROR (neg classed as pos %0.2f): the design is sleek and the color screen has good resolution .
# ERROR (neg classed as pos %0.2f): but , i would definately recommend this phone .
# ERROR (pos classed as neg %0.2f): after several years of torture in the hands of at&t customer service i am delighted to drop them , and look forward to august 2004 when i will convert our other 3 family-phones from at&t to t-mobile !
# ERROR (neg classed as pos %0.2f): the day finally arrived when i was sure i 'd leave sprint .
# ERROR (neg classed as pos %0.2f): after years with that carrier 's expensive plans and horrible customer service , portability seemed heaven-sent .
# ERROR (pos classed as neg %0.2f): the headset that comes with the phone has good sound volume but it hurts the ears like you cannot imagine !
# ERROR (pos classed as neg %0.2f): the colors on the screen are not as crisp as i 'd have liked them to be .
# ERROR (pos classed as neg %0.2f): the menu options are uncreative , as you can 't see a full screen of menu items to pick from ; you have to scroll up and down to find what you 're looking for ( yes , this is minor , but not when you 're trying to keep your eye on the road ! ) .
# ERROR (neg classed as pos %0.2f): i have excellent hearing but the volume level on this phone is especially quiet .
# ERROR (pos classed as neg %0.2f): however , the calls constantly drop in my area and i experince mega-static , to the point where i 'd have to dial numbers 6-7 times to get a clear line .
# ERROR (neg classed as pos %0.2f): the more subtle tones that were included with the phone are hard to hear at times .
# ERROR (pos classed as neg %0.2f): great battery life , perfect size , but a tid bit quieter than i would like .
# ERROR (neg classed as pos %0.2f): radio is awsome , but it does n't work unless you have the earpice in .
# ERROR (neg classed as pos %0.2f): it also does n't have voice activated dialing . big minus ! !
# ERROR (pos classed as neg %0.2f): we got two phones for the t-mobile family plan ( indeed very easy to switch to the family plan ) and one came with a broken headphone ( can hear but cannot be heard ) and one died today after less than two weeks of use .
# ERROR (neg classed as pos %0.2f): games kind of stink and you cant download them you have to get the link cable to get additional games .
# ERROR (neg classed as pos %0.2f): buttons do seem a little sticky tho .. and the hands free kits ' connector might be a problem ..
# ERROR (neg classed as pos %0.2f): there are some features in the user interface that i find a little inconvenient .
# ERROR (pos classed as neg %0.2f): the menu options appear one at a time , taking up the whole screen , and one has to scroll down one by one , or have memorized where they are in the menu order , to select them by using the number keypad .
# ERROR (neg classed as pos %0.2f): - no option for caller-id pictures or individualized ringtones .
# ERROR (neg classed as pos %0.2f): - no propietary headset jack
# ERROR (pos classed as neg %0.2f): the volume key can be hard to press , but i think this may be by design rather than a flaw , perhaps to keep you from pressing it accidentally when you are in a call .
# ERROR (neg classed as pos %0.2f): i thought this was the ultimate phone when it comes to basic features , but i was dissapointed when i saw that it was only a gsm comaptible phone .
# ERROR (neg classed as pos %0.2f): its quiet .
# ERROR (neg classed as pos %0.2f): although i find it more convenient to use 1-touch dialing , this phone does not have voice dialing .
# ERROR (neg classed as pos %0.2f): in my opinion the worst issue on this phone is the side-mounted volume control .
# ERROR (neg classed as pos %0.2f): one complaint ... the screen is too easily scratched !
# ERROR (neg classed as pos %0.2f): my only gripe about the hardware is the buttons .
# ERROR (pos classed as neg %0.2f): this model does have the traditional key arrangement , it 's just that they are really close to one another , and have unconventional shapes , so it takes a big getting used to for someone like me with big hands .
# ERROR (pos classed as neg %0.2f): the gprs connection is sometimes slow , and writing instant messages with the included aol instant messenger software is a pain , but the other t-zones applications are quite useful .
# ERROR (pos classed as neg %0.2f): the internet functions of the phone - wap and gprs - will only work through t-mobile 's services , because they have deleted the menu options that would enable you to configure the phone to be used on a different network .
# ERROR (neg classed as pos %0.2f): when talking the voice is not very clear .
# Sigma: 2.22
# Threshold: -25.15
# Mean score: -43.222627737226276
# Accuracy (All)=0.62 (170/274)
#
# Positive scores..
# Precision (Pos)=0.73 (144/198)
# Recall (Pos)=0.74 (144/194)
# F-measure (Pos)=0.73
# Negative scores..
# Precision (Neg)=0.34 (26/76)
# Recall (Neg)=0.32 (26/80)
# F-measure (Neg)=0.33
#
# Mean scores..
# Precision (Mean)=0.53
# Recall (Mean)=0.53
# F-measure (Mean)=0.53
